# %%
#load libraries
import pandas as pd
import re

# %%
import os
from requests import get
from urllib.parse import urlparse

def cache_data(src:str, dest:str) -> str:
    """Downloads and caches a remote file locally.
    
    The function sits between the 'read' step of a pandas or geopandas
    data frame and downloading the file from a remote location. The idea
    is that it will save it locally so that you don't need to remember to
    do so yourself. Subsequent re-reads of the file will return instantly
    rather than downloading the entire file for a second or n-th itme.
    
    Parameters
    ----------
    src : str
        The remote *source* for the file, any valid URL should work.
    dest : str
        The *destination* location to save the downloaded file.
        
    Returns
    -------
    str
        A string representing the local location of the file.
    """
    
    url = urlparse(src) # We assume that this is some kind of valid URL 
    fn  = os.path.split(url.path)[-1] # Extract the filename
    dfn = os.path.join(dest,fn) # Destination filename
    
    # Check if dest+filename does *not* exist -- 
    # that would mean we have to download it!
    if not os.path.isfile(dfn):
        
        print(f"{dfn} not found, downloading!")

        # Convert the path back into a list (without)
        # the filename -- we need to check that directories
        # exist first.
        path = os.path.split(dest)
        
        # Create any missing directories in dest(ination) path
        # -- os.path.join is the reverse of split (as you saw above)
        # but it doesn't work with lists... so I had to google how
        # to use the 'splat' operator! os.makedirs creates missing
        # directories in a path automatically.
        if len(path) >= 1 and path[0] != '':
            os.makedirs(os.path.join(*path), exist_ok=True)
            
        # Download and write the file
        with open(dfn, "wb") as file:
            response = get(src)
            file.write(response.content)
            
        print('Done downloading...')

    else:
        print(f"Found {dfn} locally!")

    return dfn

# %% [markdown]
# # nowork_rate、middle_high_class_pro、advanced_education_rate

# %%
src_url   = 'https://data.london.gov.uk/download/2021-census-wards-labour-market/ab2e314e-dbd8-4afe-8304-1f5402eda542/NSSEC.xlsx'
dest_path = os.path.join('data','ward_socioeconomic')

status = pd.read_excel(
    cache_data(src_url, dest_path), 
    sheet_name='2021')
# Out:
# Found data/ward_socioeconomic/NSSEC.xlsx locally!

# %%
status.head()
# Out:
#    ward code          ward name local authority code  local authority name  \
# 0  E09000001     City of London            E09000001        City of London
# 1  E05014053              Abbey            E09000002  Barking and Dagenham
# 2  E05014054             Alibon            E09000002  Barking and Dagenham
# 3  E05014055  Barking Riverside            E09000002  Barking and Dagenham
# 4  E05014056               Beam            E09000002  Barking and Dagenham
#
#    All usual residents aged 16+   Higher managerial admin and professional   \
# 0                           8003                                       3173
# 1                           2940                                        455
# 2                           7458                                        419
# 3                           6901                                        680
# 4                           6092                                        305
#
#    Lower managerial admin and professional   Intermediate   \
# 0                                      1914            431
# 1                                       481            228
# 2                                      1139            769
# 3                                      1271            736
# 4                                       873            654
#
#    Small employers, own account workers  Lower supervisory and technical   \
# 0                                   571                               133
# 1                                   358                               107
# 2                                  1044                               414
# 3                                   757                               341
# 4                                   783                               320
#
#    Semi routine  Routine   Never worked and long term unemployed  \
# 0           289       257                                    441
# 1           299       308                                    415
# 2           964      1039                                    893
# 3           743       785                                    785
# 4           791       893                                    764
#
#    Full time students
# 0                 794
# 1                 289
# 2                 777
# 3                 803
# 4                 709

# %%
status.columns.to_list()
# Out:
# ['ward code',
#  'ward name',
#  'local authority code',
#  'local authority name',
#  'All usual residents aged 16+ ',
#  'Higher managerial admin and professional ',
#  'Lower managerial admin and professional ',
#  'Intermediate ',
#  'Small employers, own account workers',
#  'Lower supervisory and technical ',
#  'Semi routine',
#  'Routine ',
#  'Never worked and long term unemployed',
#  'Full time students']

# %%
# Dropping the specified columns
status = status.drop(columns=['ward code', 'local authority code', 'local authority name'])
status.head()
# Out:
#            ward name  All usual residents aged 16+   \
# 0     City of London                           8003
# 1              Abbey                           2940
# 2             Alibon                           7458
# 3  Barking Riverside                           6901
# 4               Beam                           6092
#
#    Higher managerial admin and professional   \
# 0                                       3173
# 1                                        455
# 2                                        419
# 3                                        680
# 4                                        305
#
#    Lower managerial admin and professional   Intermediate   \
# 0                                      1914            431
# 1                                       481            228
# 2                                      1139            769
# 3                                      1271            736
# 4                                       873            654
#
#    Small employers, own account workers  Lower supervisory and technical   \
# 0                                   571                               133
# 1                                   358                               107
# 2                                  1044                               414
# 3                                   757                               341
# 4                                   783                               320
#
#    Semi routine  Routine   Never worked and long term unemployed  \
# 0           289       257                                    441
# 1           299       308                                    415
# 2           964      1039                                    893
# 3           743       785                                    785
# 4           791       893                                    764
#
#    Full time students
# 0                 794
# 1                 289
# 2                 777
# 3                 803
# 4                 709

# %%
status=status.groupby('ward name').sum()

# %%
#失业率=Never worked and long term unemployed 中高产阶级人群所占比例=[5:8] 高等教育比例[Full time students]
status['nonwork_rate'] = (status['Never worked and long term unemployed']/status["All usual residents aged 16+ "]).round(2)
status['middle_high_class_pro'] = ((status['Higher managerial admin and professional '] + status['Lower managerial admin and professional '] + status['Intermediate '])/status["All usual residents aged 16+ "]).round(2)
status['advanced_education_rate'] = (status['Full time students']/status["All usual residents aged 16+ "]).round(2)

# %%
status.head()
# Out:
#                  All usual residents aged 16+   \
# ward name
# Abbey                                    11322
# Abbey Road                               11003
# Abbey Wood                               13144
# Abingdon                                  7076
# Addiscombe East                           9659
#
#                  Higher managerial admin and professional   \
# ward name
# Abbey                                                 2877
# Abbey Road                                            3520
# Abbey Wood                                            1089
# Abingdon                                              2229
# Addiscombe East                                       1610
#
#                  Lower managerial admin and professional   Intermediate   \
# ward name
# Abbey                                                2646            986
# Abbey Road                                           2250            691
# Abbey Wood                                           2062           1403
# Abingdon                                             1416            414
# Addiscombe East                                      2264           1281
#
#                  Small employers, own account workers  \
# ward name
# Abbey                                            1188
# Abbey Road                                       1047
# Abbey Wood                                       1365
# Abingdon                                          787
# Addiscombe East                                  1088
#
#                  Lower supervisory and technical   Semi routine  Routine   \
# ward name
# Abbey                                         342           822       791
# Abbey Road                                    191           545       408
# Abbey Wood                                    735          1737      1742
# Abingdon                                      106           290       204
# Addiscombe East                               418           863       713
#
#                  Never worked and long term unemployed  Full time students  \
# ward name
# Abbey                                              907                 763
# Abbey Road                                        1156                1195
# Abbey Wood                                        1645                1366
# Abingdon                                           708                 922
# Addiscombe East                                    750                 672
#
#                  nonwork_rate  middle_high_class_pro  advanced_education_rate
# ward name
# Abbey                    0.08                   0.57                     0.07
# Abbey Road               0.11                   0.59                     0.11
# Abbey Wood               0.13                   0.35                     0.10
# Abingdon                 0.10                   0.57                     0.13
# Addiscombe East          0.08                   0.53                     0.07

# %%
status = status.reset_index()
status
# Out:
#                 ward name  All usual residents aged 16+   \
# 0                   Abbey                          11322
# 1              Abbey Road                          11003
# 2              Abbey Wood                          13144
# 3                Abingdon                           7076
# 4         Addiscombe East                           9659
# ..                    ...                            ...
# 665  Worcester Park North                           6415
# 666  Worcester Park South                           5820
# 667              Wormholt                           6374
# 668               Yeading                          10153
# 669              Yiewsley                           9171
#
#      Higher managerial admin and professional   \
# 0                                         2877
# 1                                         3520
# 2                                         1089
# 3                                         2229
# 4                                         1610
# ..                                         ...
# 665                                       1205
# 666                                       1126
# 667                                        904
# 668                                        763
# 669                                       1010
#
#      Lower managerial admin and professional   Intermediate   \
# 0                                        2646            986
# 1                                        2250            691
# 2                                        2062           1403
# 3                                        1416            414
# 4                                        2264           1281
# ..                                        ...            ...
# 665                                      1478            794
# 666                                      1313            870
# 667                                      1290            614
# 668                                      1535           1023
# 669                                      1594           1044
#
#      Small employers, own account workers  Lower supervisory and technical   \
# 0                                    1188                               342
# 1                                    1047                               191
# 2                                    1365                               735
# 3                                     787                               106
# 4                                    1088                               418
# ..                                    ...                               ...
# 665                                   794                               278
# 666                                   767                               249
# 667                                   622                               276
# 668                                  1213                               571
# 669                                   911                               516
#
#      Semi routine  Routine   Never worked and long term unemployed  \
# 0             822       791                                    907
# 1             545       408                                   1156
# 2            1737      1742                                   1645
# 3             290       204                                    708
# 4             863       713                                    750
# ..            ...       ...                                    ...
# 665           533       477                                    446
# 666           489       374                                    321
# 667           549       526                                    747
# 668          1337      1257                                   1506
# 669          1053      1160                                   1120
#
#      Full time students  nonwork_rate  middle_high_class_pro  \
# 0                   763          0.08                   0.57
# 1                  1195          0.11                   0.59
# 2                  1366          0.13                   0.35
# 3                   922          0.10                   0.57
# 4                   672          0.08                   0.53
# ..                  ...           ...                    ...
# 665                 410          0.07                   0.54
# 666                 311          0.06                   0.57
# 667                 846          0.12                   0.44
# 668                 948          0.15                   0.33
# 669                 763          0.12                   0.40
#
#      advanced_education_rate
# 0                       0.07
# 1                       0.11
# 2                       0.10
# 3                       0.13
# 4                       0.07
# ..                       ...
# 665                     0.06
# 666                     0.05
# 667                     0.13
# 668                     0.09
# 669                     0.08
#
# [670 rows x 14 columns]

# %% [markdown]
# # public_transport_station_coverage

# %%
src_url   = 'https://data.london.gov.uk/download/2021-census-wards-labour-market/d9f01451-3960-4a1f-a43d-392e45aa0830/Method%20of%20travel%20to%20work.xlsx'
dest_path = os.path.join('data','ward_socioeconomic')

method_of_work = pd.read_excel(
    cache_data(src_url, dest_path), 
    sheet_name='2021')
# Out:
# Found data/ward_socioeconomic/Method%20of%20travel%20to%20work.xlsx locally!

# %%
method_of_work.columns.to_list()
# Out:
# ['ward code',
#  'ward name',
#  'local authority code',
#  'local authority name',
#  'All usual residents aged 16+ in employment',
#  'Work mainly at or from home',
#  'Under-ground; metro; light rail; tram',
#  'Train',
#  'Bus; minibus or coach',
#  'Taxi',
#  'Motorcycle; scooter or moped',
#  'Driving a car or van',
#  'Passenger in a car or van',
#  'Bicycle',
#  'On foot',
#  'Other method of travel to work']

# %%
# Dropping the specified columns
method_of_work = method_of_work.drop(columns=['ward code', 'local authority code', 'local authority name'])
method_of_work=method_of_work.groupby('ward name').sum()
method_of_work.head()
# Out:
#                  All usual residents aged 16+ in employment  \
# ward name
# Abbey                                                  8044
# Abbey Road                                             6354
# Abbey Wood                                             7707
# Abingdon                                               4019
# Addiscombe East                                        6073
#
#                  Work mainly at or from home  \
# ward name
# Abbey                                   4105
# Abbey Road                              4061
# Abbey Wood                              1827
# Abingdon                                2578
# Addiscombe East                         2589
#
#                  Under-ground; metro; light rail; tram  Train  \
# ward name
# Abbey                                             1290    394
# Abbey Road                                         595     81
# Abbey Wood                                         679    963
# Abingdon                                           356     79
# Addiscombe East                                    374    542
#
#                  Bus; minibus or coach  Taxi  Motorcycle; scooter or moped  \
# ward name
# Abbey                              443    12                            56
# Abbey Road                         328    69                            25
# Abbey Wood                        1221    35                            35
# Abingdon                           152    51                            40
# Addiscombe East                    495    15                            44
#
#                  Driving a car or van  Passenger in a car or van  Bicycle  \
# ward name
# Abbey                             912                         59      196
# Abbey Road                        426                         34      173
# Abbey Wood                       2241                        182       92
# Abingdon                          228                         42      112
# Addiscombe East                  1490                         93       63
#
#                  On foot  Other method of travel to work
# ward name
# Abbey                512                              65
# Abbey Road           496                              66
# Abbey Wood           321                             111
# Abingdon             331                              50
# Addiscombe East      300                              68

# %%
method_of_work.columns.to_list()
# Out:
# ['All usual residents aged 16+ in employment',
#  'Work mainly at or from home',
#  'Under-ground; metro; light rail; tram',
#  'Train',
#  'Bus; minibus or coach',
#  'Taxi',
#  'Motorcycle; scooter or moped',
#  'Driving a car or van',
#  'Passenger in a car or van',
#  'Bicycle',
#  'On foot',
#  'Other method of travel to work']

# %%
#select representive indicator to analyse. 
#we want to find the quantity of public transportation around places where people live, 
#so we decide to choose "Under-ground; metro; light rail; tram","Bus; minibus or coach","Train" columns to represent.
method_of_work["public_transport_station_coverage"] = ((method_of_work["Under-ground; metro; light rail; tram"]+method_of_work["Train"]+method_of_work["Bus; minibus or coach"])/(method_of_work["All usual residents aged 16+ in employment"]-method_of_work["Work mainly at or from home"])).round(2)
method_of_work.head()
# Out:
#                  All usual residents aged 16+ in employment  \
# ward name
# Abbey                                                  8044
# Abbey Road                                             6354
# Abbey Wood                                             7707
# Abingdon                                               4019
# Addiscombe East                                        6073
#
#                  Work mainly at or from home  \
# ward name
# Abbey                                   4105
# Abbey Road                              4061
# Abbey Wood                              1827
# Abingdon                                2578
# Addiscombe East                         2589
#
#                  Under-ground; metro; light rail; tram  Train  \
# ward name
# Abbey                                             1290    394
# Abbey Road                                         595     81
# Abbey Wood                                         679    963
# Abingdon                                           356     79
# Addiscombe East                                    374    542
#
#                  Bus; minibus or coach  Taxi  Motorcycle; scooter or moped  \
# ward name
# Abbey                              443    12                            56
# Abbey Road                         328    69                            25
# Abbey Wood                        1221    35                            35
# Abingdon                           152    51                            40
# Addiscombe East                    495    15                            44
#
#                  Driving a car or van  Passenger in a car or van  Bicycle  \
# ward name
# Abbey                             912                         59      196
# Abbey Road                        426                         34      173
# Abbey Wood                       2241                        182       92
# Abingdon                          228                         42      112
# Addiscombe East                  1490                         93       63
#
#                  On foot  Other method of travel to work  \
# ward name
# Abbey                512                              65
# Abbey Road           496                              66
# Abbey Wood           321                             111
# Abingdon             331                              50
# Addiscombe East      300                              68
#
#                  public_transport_station_coverage
# ward name
# Abbey                                         0.54
# Abbey Road                                    0.44
# Abbey Wood                                    0.49
# Abingdon                                      0.41
# Addiscombe East                               0.40

# %%
method_of_work.rename(columns={'Ward name': 'ward name'}, inplace=True)

# %%
method_of_work
# Out:
#                 ward name  All usual residents aged 16+ in employment  \
# 0                   Abbey                                        8044
# 1              Abbey Road                                        6354
# 2              Abbey Wood                                        7707
# 3                Abingdon                                        4019
# 4         Addiscombe East                                        6073
# ..                    ...                                         ...
# 665  Worcester Park North                                        4264
# 666  Worcester Park South                                        3583
# 667              Wormholt                                        3717
# 668               Yeading                                        5796
# 669              Yiewsley                                        5648
#
#      Work mainly at or from home  Under-ground; metro; light rail; tram  \
# 0                           4105                                   1290
# 1                           4061                                    595
# 2                           1827                                    679
# 3                           2578                                    356
# 4                           2589                                    374
# ..                           ...                                    ...
# 665                         1784                                    127
# 666                         1572                                     88
# 667                         1567                                    453
# 668                         1205                                    311
# 669                         1497                                    292
#
#      Train  Bus; minibus or coach  Taxi  Motorcycle; scooter or moped  \
# 0      394                    443    12                            56
# 1       81                    328    69                            25
# 2      963                   1221    35                            35
# 3       79                    152    51                            40
# 4      542                    495    15                            44
# ..     ...                    ...   ...                           ...
# 665    307                    190    23                            47
# 666    190                    135     7                            27
# 667    116                    378    30                            41
# 668    129                    800    49                            43
# 669    275                    667    18                            25
#
#      Driving a car or van  Passenger in a car or van  Bicycle  On foot  \
# 0                     912                         59      196      512
# 1                     426                         34      173      496
# 2                    2241                        182       92      321
# 3                     228                         42      112      331
# 4                    1490                         93       63      300
# ..                    ...                        ...      ...      ...
# 665                  1347                        102       85      206
# 666                  1243                         78       45      161
# 667                   434                         34      221      409
# 668                  2716                        186       90      174
# 669                  2152                        180       87      384
#
#      Other method of travel to work  public_transport_station_coverage
# 0                                65                               0.54
# 1                                66                               0.44
# 2                               111                               0.49
# 3                                50                               0.41
# 4                                68                               0.40
# ..                              ...                                ...
# 665                              46                               0.25
# 666                              37                               0.21
# 667                              34                               0.44
# 668                              93                               0.27
# 669                              71                               0.30
#
# [670 rows x 14 columns]

# %%
method_of_work = method_of_work.reset_index()

# %% [markdown]
# # commute_distance

# %%
src_url   = ' https://data.london.gov.uk/download/2021-census-wards-labour-market/7725cc70-ab2b-4674-99cb-b825bc9ef4ca/Distance%20traveled%20to%20work.xlsx'
dest_path = os.path.join('data','ward_socioeconomic')

commute_distance = pd.read_excel(
    cache_data(src_url, dest_path), 
    sheet_name='2021')
# Out:
# Found data/ward_socioeconomic/Distance%20traveled%20to%20work.xlsx locally!

# %%
commute_distance.columns.to_list()
# Out:
# ['ward code',
#  'ward name',
#  'local authority code',
#  'local authority name',
#  'All usual residents aged 16+ in employment',
#  'Less than 2km',
#  '2km to less than 5km',
#  '5km to less than 10km',
#  '10km to less than 20km',
#  '20km to less than 30km',
#  '30km to less than 40km',
#  '40km to less than 60km',
#  '60km and over',
#  'Works mainly from home',
#  'Other']

# %%
# Dropping the specified columns
commute_distance = commute_distance.drop(columns=['ward code', 'local authority code', 'local authority name'])
commute_distance=commute_distance.groupby('ward name').sum()
commute_distance.head()
# Out:
#                  All usual residents aged 16+ in employment  Less than 2km  \
# ward name
# Abbey                                                  8042            588
# Abbey Road                                             6354            366
# Abbey Wood                                             7692            480
# Abingdon                                               4013            299
# Addiscombe East                                        6082            382
#
#                  2km to less than 5km  5km to less than 10km  \
# ward name
# Abbey                             520                    786
# Abbey Road                        772                    435
# Abbey Wood                       1013                   1027
# Abingdon                          439                    281
# Addiscombe East                   719                    559
#
#                  10km to less than 20km  20km to less than 30km  \
# ward name
# Abbey                               971                     116
# Abbey Road                          209                      27
# Abbey Wood                         1403                     248
# Abingdon                             79                      10
# Addiscombe East                     758                     122
#
#                  30km to less than 40km  40km to less than 60km  \
# ward name
# Abbey                                33                      24
# Abbey Road                           13                      11
# Abbey Wood                          101                      27
# Abingdon                              9                      14
# Addiscombe East                      45                      30
#
#                  60km and over  Works mainly from home  Other
# ward name
# Abbey                       48                    4105    851
# Abbey Road                  27                    4061    433
# Abbey Wood                  86                    1827   1480
# Abingdon                    24                    2578    280
# Addiscombe East             32                    2589    846

# %%
commute_distance["average_commute_distance"] = ((commute_distance["Less than 2km"]*1+commute_distance["2km to less than 5km"]*3.5+commute_distance["5km to less than 10km"]*7.5+commute_distance["10km to less than 20km"]*15+commute_distance["20km to less than 30km"]*25+commute_distance["30km to less than 40km"]*35+commute_distance["40km to less than 60km"]*50+commute_distance["60km and over"]*60)/commute_distance["All usual residents aged 16+ in employment"]).round(2)

# %%
commute_distance.head()
# Out:
#                  All usual residents aged 16+ in employment  Less than 2km  \
# ward name
# Abbey                                                  8042            588
# Abbey Road                                             6354            366
# Abbey Wood                                             7692            480
# Abingdon                                               4013            299
# Addiscombe East                                        6082            382
#
#                  2km to less than 5km  5km to less than 10km  \
# ward name
# Abbey                             520                    786
# Abbey Road                        772                    435
# Abbey Wood                       1013                   1027
# Abingdon                          439                    281
# Addiscombe East                   719                    559
#
#                  10km to less than 20km  20km to less than 30km  \
# ward name
# Abbey                               971                     116
# Abbey Road                          209                      27
# Abbey Wood                         1403                     248
# Abingdon                             79                      10
# Addiscombe East                     758                     122
#
#                  30km to less than 40km  40km to less than 60km  \
# ward name
# Abbey                                33                      24
# Abbey Road                           13                      11
# Abbey Wood                          101                      27
# Abingdon                              9                      14
# Addiscombe East                      45                      30
#
#                  60km and over  Works mainly from home  Other  \
# ward name
# Abbey                       48                    4105    851
# Abbey Road                  27                    4061    433
# Abbey Wood                  86                    1827   1480
# Abingdon                    24                    2578    280
# Addiscombe East             32                    2589    846
#
#                  average_commute_distance
# ward name
# Abbey                                3.86
# Abbey Road                           2.01
# Abbey Wood                           6.37
# Abingdon                             1.95
# Addiscombe East                      4.36

# %%
commute_distance.rename(columns={'Ward name': 'ward name'}, inplace=True)

# %%
commute_distance = commute_distance.reset_index()

# %% [markdown]
# # uhealthy_rate、usual_residents

# %%
src_url   = 'https://data.london.gov.uk/download/2021-census-wards-qualifications-health-disability-and-care/af5f35f0-fdd3-4531-9616-ff1f1a64101a/General%20health.xlsx'
dest_path = os.path.join('data','ward_socioeconomic')

health = pd.read_excel(
    cache_data(src_url, dest_path), 
    sheet_name='2021')
# Out:
# Found data/ward_socioeconomic/General%20health.xlsx locally!

# %%
health.columns.to_list()
# Out:
# ['ward code',
#  'ward name',
#  'local authority code',
#  'local authority name',
#  'All Usual residents ',
#  'Very good health',
#  'Good health',
#  'Fair health',
#  'Bad health',
#  'Very bad health']

# %%
# Dropping the specified columns
health = health.drop(columns=['ward code', 'local authority code', 'local authority name'])
health=health.groupby('ward name').sum()
health.head()
# Out:
#                  All Usual residents   Very good health  Good health  \
# ward name
# Abbey                           14229              8184         4477
# Abbey Road                      12977              7800         3610
# Abbey Wood                      17425              9173         5475
# Abingdon                         8158              5072         2236
# Addiscombe East                 11802              5852         4189
#
#                  Fair health  Bad health  Very bad health
# ward name
# Abbey                   1188         275              105
# Abbey Road              1051         355              161
# Abbey Wood              1917         671              189
# Abingdon                 604         180               66
# Addiscombe East         1266         351              144

# %%
#i think bad health rate can be representaive
health['unhealthy_rate']=((health['Bad health']+health['Very bad health'])/health['All Usual residents ']).round(2)

# %%
health.rename(columns={'All Usual residents ': 'All Usual residents'}, inplace=True)

# %%
health.head()
# Out:
#                  All Usual residents  Very good health  Good health  \
# ward name
# Abbey                          14229              8184         4477
# Abbey Road                     12977              7800         3610
# Abbey Wood                     17425              9173         5475
# Abingdon                        8158              5072         2236
# Addiscombe East                11802              5852         4189
#
#                  Fair health  Bad health  Very bad health  unhealthy_rate
# ward name
# Abbey                   1188         275              105            0.03
# Abbey Road              1051         355              161            0.04
# Abbey Wood              1917         671              189            0.05
# Abingdon                 604         180               66            0.03
# Addiscombe East         1266         351              144            0.04

# %%
health = health.reset_index()

# %% [markdown]
# # disability

# %%
src_url   = 'https://data.london.gov.uk/download/2021-census-wards-qualifications-health-disability-and-care/a9f40c75-fbe5-4a52-acc5-d5a9ac496c4d/Disability.xlsx'
dest_path = os.path.join('data','ward_socioeconomic')

disability = pd.read_excel(
    cache_data(src_url, dest_path), 
    sheet_name='2021')
# Out:
# Found data/ward_socioeconomic/Disability.xlsx locally!

# %%
disability.columns.to_list()
# Out:
# ['ward code',
#  'ward name',
#  'local authority code',
#  'local authority name',
#  'All Usual residents ',
#  'Disabled; activities limited a lot',
#  'Disabled; activities limited a little',
#  'Not disabled']

# %%
# Dropping the specified columns
disability = disability.drop(columns=['ward code', 'local authority code', 'local authority name'])
disability=disability.groupby('ward name').sum()
disability.head()
# Out:
#                  All Usual residents   Disabled; activities limited a lot  \
# ward name
# Abbey                           14230                                 498
# Abbey Road                      12987                                 689
# Abbey Wood                      17422                                1306
# Abingdon                         8162                                 294
# Addiscombe East                 11798                                 638
#
#                  Disabled; activities limited a little  Not disabled
# ward name
# Abbey                                              921         12811
# Abbey Road                                         737         11561
# Abbey Wood                                        1302         14814
# Abingdon                                           485          7383
# Addiscombe East                                   1017         10143

# %%
disability['disabled_pro'] = ((disability['Disabled; activities limited a lot']+disability['Disabled; activities limited a little'])/disability['All Usual residents ']).round(2)

# %%
disability.head()
# Out:
#                  All Usual residents   Disabled; activities limited a lot  \
# ward name
# Abbey                           14230                                 498
# Abbey Road                      12987                                 689
# Abbey Wood                      17422                                1306
# Abingdon                         8162                                 294
# Addiscombe East                 11798                                 638
#
#                  Disabled; activities limited a little  Not disabled  \
# ward name
# Abbey                                              921         12811
# Abbey Road                                         737         11561
# Abbey Wood                                        1302         14814
# Abingdon                                           485          7383
# Addiscombe East                                   1017         10143
#
#                  disabled_pro
# ward name
# Abbey                    0.10
# Abbey Road               0.11
# Abbey Wood               0.15
# Abingdon                 0.10
# Addiscombe East          0.14

# %%
disability = disability.reset_index()

# %% [markdown]
# # house_sale_price

# %%
houseprice = pd.read_excel(("data/ward_socioeconomic/HPSSA Dataset 37 - Median price paid by ward.xls"),
                           sheet_name='1a',
                           header=[5])

# %%
houseprice2=houseprice[
    houseprice["Local authority code"].str.contains(r'E090000(?:0[1-9]|1[0-9]|2[0-9]|3[0-1])'
, regex=True, flags=re.IGNORECASE) 
]
houseprice2.head()
# Out:
#      Local authority code Local authority name  Ward code           Ward name  \
# 6561            E09000001       City of London  E05009288          Aldersgate
# 6562            E09000001       City of London  E05009292         Bishopsgate
# 6563            E09000001       City of London  E05009302         Cripplegate
# 6564            E09000001       City of London  E05009304   Farringdon Within
# 6565            E09000001       City of London  E05009305  Farringdon Without
#
#      Year ending Dec 1995 Year ending Mar 1996 Year ending Jun 1996  \
# 6561               100000               106250               112375
# 6562                    :               183750               178750
# 6563               111250               113000               110000
# 6564                    :                    :                    :
# 6565                86500               115000               115000
#
#      Year ending Sep 1996 Year ending Dec 1996 Year ending Mar 1997  ...  \
# 6561               120250               121500             130076.5  ...
# 6562               178750               178750                    :  ...
# 6563               114000               113500               115000  ...
# 6564                    :               195000               195000  ...
# 6565               139000               125000               116000  ...
#
#      Year ending Dec 2020 Year ending Mar 2021 Year ending Jun 2021  \
# 6561               775000               750000               687500
# 6562                    :                    :                    :
# 6563               797500               792500               787500
# 6564                    :                    :                    :
# 6565              1132125               840000               827700
#
#      Year ending Sep 2021 Year ending Dec 2021 Year ending Mar 2022  \
# 6561               712500               751250               720000
# 6562                    :              1250850              1259550
# 6563               800000               805000               797500
# 6564                    :                    :               870000
# 6565               805000               812000               846300
#
#      Year ending Jun 2022 Year ending Sep 2022 Year ending Dec 2022  \
# 6561               722500               730000               745000
# 6562              1259550              1296900              1445300
# 6563               797500               805000               810000
# 6564               870000               783500               897500
# 6565               820000               810000               800000
#
#      Year ending Mar 2023
# 6561               770000
# 6562              1642650
# 6563               842500
# 6564               925000
# 6565              1005678
#
# [5 rows x 114 columns]

# %%
# Selecting the relevant columns for the year 2022
columns_2022 = ['Ward name', 'Year ending Mar 2022', 'Year ending Jun 2022', 'Year ending Sep 2022', 'Year ending Dec 2022']

# Create a new dataframe with only the relevant columns
houseprice_2022 = houseprice2[columns_2022]

# Replace ':' with NaN (to handle missing values) and convert the columns to numeric
houseprice_2022.replace(':', pd.NA, inplace=True)
houseprice_2022 = houseprice_2022.apply(pd.to_numeric, errors='ignore')

# Display the dataframe after modifications and the summary of missing values
houseprice_2022.head()
houseprice_2022.isna().sum()
# Out:
# /tmp/ipykernel_751/2781558586.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   houseprice_2022.replace(':', pd.NA, inplace=True)
# Ward name               0
# Year ending Mar 2022    1
# Year ending Jun 2022    2
# Year ending Sep 2022    1
# Year ending Dec 2022    1
# dtype: int64

# %%
houseprice_2022 = houseprice_2022.set_index('Ward name')

# %%
houseprice_2022=houseprice_2022.groupby('Ward name').sum()

# %%
houseprice_2022['median_houseprice_2022'] = houseprice_2022[
    ['Year ending Mar 2022', 'Year ending Jun 2022', 'Year ending Sep 2022', 'Year ending Dec 2022']
].median(axis=1, skipna=True)

# Display the updated dataframe with the median house price column
houseprice_2022.sample(3)
# Out:
#                           Year ending Mar 2022  Year ending Jun 2022  \
# Ward name
# Pembridge                            1350000.0             1295000.0
# Avonmore and Brook Green              627000.0              602500.0
# Haggerston                            518000.0              506250.0
#
#                           Year ending Sep 2022  Year ending Dec 2022  \
# Ward name
# Pembridge                            1295000.0             1275000.0
# Avonmore and Brook Green              588750.0              590000.0
# Haggerston                            525000.0              507000.0
#
#                           median_houseprice_2022
# Ward name
# Pembridge                              1295000.0
# Avonmore and Brook Green                596250.0
# Haggerston                              512500.0

# %%
houseprice_2022.rename(columns={'Ward name': 'ward name'}, inplace=True)

# %%
houseprice_2022.shape[0]
# Out:
# 585

# %%
houseprice_2022.head()
# Out:
#          ward name  Year ending Mar 2022  Year ending Jun 2022  \
# 0            Abbey              953000.0              973000.0
# 1       Abbey Wood              375000.0              380000.0
# 2         Abingdon             1430000.0             1400000.0
# 3    Acton Central              570000.0              600000.0
# 4  Addiscombe East              440000.0              435000.0
#
#    Year ending Sep 2022  Year ending Dec 2022  median_houseprice_2022
# 0              980200.0              995000.0                976600.0
# 1              390000.0              400000.0                385000.0
# 2             1440000.0             1440000.0               1435000.0
# 3              706250.0              652500.0                626250.0
# 4              442000.0              457538.0                441000.0

# %%
houseprice_2022 = houseprice_2022.reset_index()

# %% [markdown]
# # house_rent_price

# %%
house_rent_price = pd.read_excel(("data/ward_socioeconomic/London Living Rent ward benchmark data 2023-24_0.xlsx"),
    )

# %%
house_rent_price.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 680 entries, 0 to 679
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Local authority  680 non-null    object
#  1   Ward             680 non-null    object
#  2   One bedroom      680 non-null    float64
#  3   Two bedrooms     680 non-null    float64
#  4   Three bedrooms   680 non-null    float64
#  5   Four bedrooms    680 non-null    float64
#  6   Five bedrooms    680 non-null    float64
#  7   Six bedrooms     680 non-null    float64
# dtypes: float64(6), object(2)
# memory usage: 42.6+ KB

# %%
house_rent_price.columns.to_list()
# Out:
# ['Local authority',
#  'Ward',
#  'One bedroom',
#  'Two bedrooms',
#  'Three bedrooms',
#  'Four bedrooms',
#  'Five bedrooms',
#  'Six bedrooms']

# %%
# Dropping the specified columns
house_rent_price = house_rent_price.drop(columns=['Local authority'])
house_rent_price=house_rent_price.groupby('Ward').sum()
house_rent_price.head()
# Out:
#                  One bedroom  Two bedrooms  Three bedrooms  Four bedrooms  \
# Ward
# Abbey            1994.915499   2216.572776     2438.230054    2624.573552
# Abbey Road       1204.003737   1337.781930     1400.000000    1400.000000
# Abbey Wood        915.608079   1017.342310     1119.076541    1220.810772
# Abingdon         1345.228828   1400.000000     1400.000000    1400.000000
# Addiscombe East  1108.071851   1231.190945     1354.310040    1400.000000
#
#                  Five bedrooms  Six bedrooms
# Ward
# Abbey              2726.621349        2800.0
# Abbey Road         1400.000000        1400.0
# Abbey Wood         1322.545003        1400.0
# Abingdon           1400.000000        1400.0
# Addiscombe East    1400.000000        1400.0

# %%
house_rent_price['mean_rent_price'] = (house_rent_price.iloc[:, 1:].mean(axis=1)).round(2)
house_rent_price.head()
# Out:
#                  One bedroom  Two bedrooms  Three bedrooms  Four bedrooms  \
# Ward
# Abbey            1994.915499   2216.572776     2438.230054    2624.573552
# Abbey Road       1204.003737   1337.781930     1400.000000    1400.000000
# Abbey Wood        915.608079   1017.342310     1119.076541    1220.810772
# Abingdon         1345.228828   1400.000000     1400.000000    1400.000000
# Addiscombe East  1108.071851   1231.190945     1354.310040    1400.000000
#
#                  Five bedrooms  Six bedrooms  mean_rent_price
# Ward
# Abbey              2726.621349        2800.0          2563.59
# Abbey Road         1400.000000        1400.0          1387.90
# Abbey Wood         1322.545003        1400.0          1217.33
# Abingdon           1400.000000        1400.0          1400.00
# Addiscombe East    1400.000000        1400.0          1357.98

# %%
house_rent_price.rename(columns={'Ward': 'ward name'}, inplace=True)

# %%
house_rent_price = house_rent_price.reset_index()

# %%
house_rent_price
# Out:
#                 ward name  One bedroom  Two bedrooms  Three bedrooms  \
# 0                   Abbey  1994.915499   2216.572776     2438.230054
# 1              Abbey Road  1204.003737   1337.781930     1400.000000
# 2              Abbey Wood   915.608079   1017.342310     1119.076541
# 3                Abingdon  1345.228828   1400.000000     1400.000000
# 4         Addiscombe East  1108.071851   1231.190945     1354.310040
# ..                    ...          ...           ...             ...
# 665  Worcester Park North  1175.388013   1305.986681     1400.000000
# 666  Worcester Park South  1175.676169   1306.306854     1400.000000
# 667              Wormholt  1094.705403   1216.339337     1337.973270
# 668               Yeading   907.274258   1008.082509     1108.890759
# 669              Yiewsley  1049.656331   1166.284812     1282.913294
#
#      Four bedrooms  Five bedrooms  Six bedrooms  mean_rent_price
# 0      2624.573552    2726.621349        2800.0          2563.59
# 1      1400.000000    1400.000000        1400.0          1387.90
# 2      1220.810772    1322.545003        1400.0          1217.33
# 3      1400.000000    1400.000000        1400.0          1400.00
# 4      1400.000000    1400.000000        1400.0          1357.98
# ..             ...            ...           ...              ...
# 665    1400.000000    1400.000000        1400.0          1381.72
# 666    1400.000000    1400.000000        1400.0          1381.78
# 667    1400.000000    1400.000000        1400.0          1351.80
# 668    1209.699010    1310.507261        1400.0          1208.82
# 669    1399.541775    1400.000000        1400.0          1330.88
#
# [670 rows x 8 columns]

# %% [markdown]
# # crime

# %%
crime = pd.read_csv("data/ward_socioeconomic/MPS Ward Level Crime (most recent 24 months).csv")

# %%
crime.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23453 entries, 0 to 23452
# Data columns (total 29 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   MajorText           23453 non-null  object
#  1   MinorText           23453 non-null  object
#  2   WardName            23453 non-null  object
#  3   WardCode            23453 non-null  object
#  4   LookUp_BoroughName  23453 non-null  object
#  5   202111              23453 non-null  int64
#  6   202112              23453 non-null  int64
#  7   202201              23453 non-null  int64
#  8   202202              23453 non-null  int64
#  9   202203              23453 non-null  int64
#  10  202204              23453 non-null  int64
#  11  202205              23453 non-null  int64
#  12  202206              23453 non-null  int64
#  13  202207              23453 non-null  int64
#  14  202208              23453 non-null  int64
#  15  202209              23453 non-null  int64
#  16  202210              23453 non-null  int64
#  17  202211              23453 non-null  int64
#  18  202212              23453 non-null  int64
#  19  202301              23453 non-null  int64
#  20  202302              23453 non-null  int64
#  21  202303              23453 non-null  int64
#  22  202304              23453 non-null  int64
#  23  202305              23453 non-null  int64
#  24  202306              23453 non-null  int64
#  25  202307              23453 non-null  int64
#  26  202308              23453 non-null  int64
#  27  202309              23453 non-null  int64
#  28  202310              23453 non-null  int64
# dtypes: int64(24), object(5)
# memory usage: 5.2+ MB

# %%
# Dropping the specified columns
crime = crime.drop(columns=['MajorText', 'MinorText', 'LookUp_BoroughName', 'WardCode'])

# Grouping by 'WardName' and summing up the crime counts for each month
crime = crime.groupby('WardName').sum()

crime.head()
# Out:
#                  202111  202112  202201  202202  202203  202204  202205  \
# WardName
# Abbey               188     177     187     184     208     165     178
# Abbey Road           59      57      69      40      65      42      41
# Abbey Wood          145     114     146     120     144     104     109
# Abingdon             73      57      61      52      87      87      76
# Addiscombe East     100      77      76      58      79      72      72
#
#                  202206  202207  202208  ...  202301  202302  202303  202304  \
# WardName                                 ...
# Abbey               172     184     184  ...     177     201     200     203
# Abbey Road           72      57      78  ...      69      67      56      68
# Abbey Wood          144     124     131  ...     120     134     125     121
# Abingdon             70      76      56  ...      83      49      64      63
# Addiscombe East      73      76      66  ...      82      63      71      74
#
#                  202305  202306  202307  202308  202309  202310
# WardName
# Abbey               187     208     203     198     214     217
# Abbey Road           58      82      71      74      54      70
# Abbey Wood          151     143     121     122     152     120
# Abingdon             85      75      89      84     106      83
# Addiscombe East      79      48      89      63      76      90
#
# [5 rows x 24 columns]

# %%
# Selecting the relevant columns for the year 2022
columns_2023 = crime[['202301','202302','202303','202304','202305',
                '202306','202307','202308','202309','202310']]
columns_2023
# Out:
#                       202301  202302  202303  202304  202305  202306  202307  \
# WardName
# Abbey                    177     201     200     203     187     208     203
# Abbey Road                69      67      56      68      58      82      71
# Abbey Wood               120     134     125     121     151     143     121
# Abingdon                  83      49      64      63      85      75      89
# Addiscombe East           82      63      71      74      79      48      89
# ...                      ...     ...     ...     ...     ...     ...     ...
# Worcester Park North      38      29      35      41      51      42      22
# Worcester Park South      11      20      19      10      21      11      24
# Wormholt                  50      47      42      29      46      33      47
# Yeading                  111     101     101      91     114     125      90
# Yiewsley                 118      98      71      90     102     130     133
#
#                       202308  202309  202310
# WardName
# Abbey                    198     214     217
# Abbey Road                74      54      70
# Abbey Wood               122     152     120
# Abingdon                  84     106      83
# Addiscombe East           63      76      90
# ...                      ...     ...     ...
# Worcester Park North      26      29      27
# Worcester Park South      12      20       9
# Wormholt                  37      59      38
# Yeading                  130     117     112
# Yiewsley                 106     124     114
#
# [669 rows x 10 columns]

# %%
crime_2023['average_crime']= crime_2023.iloc[:,1:].mean(axis=1).round(2)

# %%
crime_2023.rename(columns={'WardName': 'ward name'}, inplace=True)

# %%
crime_2023 = crime_2023.reset_index()

# %% [markdown]
# # religon

# %%
src_url   = 'https://data.london.gov.uk/download/2021-census-wards-ethnicity-language-identity-religion/7bb0ed88-e92f-4084-bdc6-66c6f1cba9f9/Religion.xlsx'
dest_path = os.path.join('data','ward_socioeconomic')

religon = pd.read_excel(
    cache_data(src_url, dest_path), 
    sheet_name='2021')
# Out:
# Found data/ward_socioeconomic/Religion.xlsx locally!

# %%
religon.head()
# Out:
#    ward code                    ward name local authority code  \
# 0  E09000001  City of London (aggregated)            E09000001
# 1  E05014053                        Abbey            E09000002
# 2  E05014054                       Alibon            E09000002
# 3  E05014055            Barking Riverside            E09000002
# 4  E05014056                         Beam            E09000002
#
#    local authority name  All usual residents  Christian  Buddhist  Hindu  \
# 0        City of London                 8586       2981        94    203
# 1  Barking and Dagenham                 3962       1355        28    728
# 2  Barking and Dagenham                 9883       5114        26    154
# 3  Barking and Dagenham                10066       4882        46    209
# 4  Barking and Dagenham                 8355       4551        30    141
#
#    Jewish  Muslim  Sikh  Other religion  No religion  Religion not stated
# 0     180     538     8              54         3762                  766
# 1       2    1060   160              23          388                  218
# 2       8    1661    58              21         2247                  594
# 3       4    2560    79              50         1698                  538
# 4      10    1615   148              34         1362                  464

# %% [markdown]
# # Ethnic group

# %%
src_url   = 'https://data.london.gov.uk/download/2021-census-wards-ethnicity-language-identity-religion/4243a044-6b22-4d32-8dbe-9113526b1976/Ethnic%20group.xlsx'
dest_path = os.path.join('data','ward_socioeconomic')

ethnic_group = pd.read_excel(
    cache_data(src_url, dest_path), 
    sheet_name='2021')
# Out:
# Found data/ward_socioeconomic/Ethnic%20group.xlsx locally!

# %%
ethnic_group.head()
# Out:
#    ward code                    ward name local authority code  \
# 0  E09000001  City of London (aggregated)            E09000001
# 1  E05014053                        Abbey            E09000002
# 2  E05014054                       Alibon            E09000002
# 3  E05014055            Barking Riverside            E09000002
# 4  E05014056                         Beam            E09000002
#
#    local authority name  All usual residents  White British  White Irish  \
# 0        City of London                 8584           3652          186
# 1  Barking and Dagenham                 3963            447           17
# 2  Barking and Dagenham                 9889           3845           71
# 3  Barking and Dagenham                10055           1943           23
# 4  Barking and Dagenham                 8360           2488           73
#
#    White Gypsy/Irish Traveller  White Roma  White Other  ...  \
# 0                            0          62         2065  ...
# 1                            3          34          691  ...
# 2                           15          47         1555  ...
# 3                            3          18         1163  ...
# 4                           17          25         1202  ...
#
#    Asian Bangladeshi  Asian Chinese  Asian Indian  Asian Pakistani  \
# 0                283            544           322               32
# 1                346             87           968              358
# 2                859             67           247              282
# 3                969             91           374              593
# 4                699             41           301              358
#
#    Asian Other  Black African  Black Caribbean  Black Other  Other Arab  \
# 0          259            150               54           26         113
# 1          131            453               68           70          42
# 2          296           1529              214          237          57
# 3          201           2815              402          547          92
# 4          156           1814              251          297          39
#
#    Other Any other
# 0              369
# 1              125
# 2              240
# 3              247
# 4              256
#
# [5 rows x 24 columns]

# %% [markdown]
# # age

# %%
src_url   = 'https://data.london.gov.uk/download/2021-census-wards-demography-and-migration/35b33393-f355-431b-9f87-ae55addaa636/Five%20year%20age%20bands.xlsx'
dest_path = os.path.join('data','ward_socioeconomic')

age = pd.read_excel(
    cache_data(src_url, dest_path), 
    sheet_name='2021')
# Out:
# Found data/ward_socioeconomic/Five%20year%20age%20bands.xlsx locally!

# %%
age.columns.to_list()
# Out:
# ['ward code',
#  'ward name',
#  'local authority code',
#  'local authority name',
#  'All usual residents',
#  'Aged 4 years and under',
#  'Aged 5 to 9 years',
#  'Aged 10 to 14 years',
#  'Aged 15 to 19 years',
#  'Aged 20 to 24 years',
#  'Aged 25 to 29 years',
#  'Aged 30 to 34 years',
#  'Aged 35 to 39 years',
#  'Aged 40 to 44 years',
#  'Aged 45 to 49 years',
#  'Aged 50 to 54 years',
#  'Aged 55 to 59 years',
#  'Aged 60 to 64 years',
#  'Aged 65 to 69 years',
#  'Aged 70 to 74 years',
#  'Aged 75 to 79 years',
#  'Aged 80 to 84 years',
#  'Aged 85 years and over']

# %%
# Dropping the specified columns
age = age.drop(columns=['ward code', 'local authority code', 'local authority name'])
age=age.groupby('ward name').sum()
age.head()
# Out:
#                  All usual residents  Aged 4 years and under  \
# ward name
# Abbey                          14225                    1121
# Abbey Road                     12980                     589
# Abbey Wood                     17417                    1147
# Abingdon                        8180                     356
# Addiscombe East                11794                     780
#
#                  Aged 5 to 9 years  Aged 10 to 14 years  Aged 15 to 19 years  \
# ward name
# Abbey                          948                  697                  512
# Abbey Road                     612                  669                  580
# Abbey Wood                    1394                 1475                 1114
# Abingdon                       343                  355                  279
# Addiscombe East                612                  620                  565
#
#                  Aged 20 to 24 years  Aged 25 to 29 years  \
# ward name
# Abbey                            728                 1649
# Abbey Road                       864                 1176
# Abbey Wood                      1029                 1283
# Abingdon                         736                  760
# Addiscombe East                  647                  833
#
#                  Aged 30 to 34 years  Aged 35 to 39 years  \
# ward name
# Abbey                           1826                 1624
# Abbey Road                      1345                 1092
# Abbey Wood                      1336                 1384
# Abingdon                         656                  630
# Addiscombe East                  976                  941
#
#                  Aged 40 to 44 years  Aged 45 to 49 years  \
# ward name
# Abbey                           1299                  950
# Abbey Road                      1004                  916
# Abbey Wood                      1265                 1204
# Abingdon                         539                  691
# Addiscombe East                  827                  767
#
#                  Aged 50 to 54 years  Aged 55 to 59 years  \
# ward name
# Abbey                            776                  625
# Abbey Road                       934                  735
# Abbey Wood                      1198                 1054
# Abingdon                         672                  524
# Addiscombe East                  869                  863
#
#                  Aged 60 to 64 years  Aged 65 to 69 years  \
# ward name
# Abbey                            453                  328
# Abbey Road                       561                  474
# Abbey Wood                       829                  606
# Abingdon                         451                  328
# Addiscombe East                  698                  553
#
#                  Aged 70 to 74 years  Aged 75 to 79 years  \
# ward name
# Abbey                            277                  186
# Abbey Road                       481                  355
# Abbey Wood                       415                  315
# Abingdon                         346                  238
# Addiscombe East                  510                  304
#
#                  Aged 80 to 84 years  Aged 85 years and over
# ward name
# Abbey                            104                     122
# Abbey Road                       279                     314
# Abbey Wood                       179                     190
# Abingdon                         141                     135
# Addiscombe East                  241                     188

# %%
age['young_people']=((age['Aged 15 to 19 years']+age['Aged 20 to 24 years'])/age['All usual residents']).round(2)
age['children_teenager']=((age['Aged 4 years and under']+age['Aged 5 to 9 years']+age['Aged 10 to 14 years'])/age['All usual residents']).round(2)
age['old_people']=((age['Aged 65 to 69 years']+age['Aged 70 to 74 years']+age['Aged 75 to 79 years']+age['Aged 80 to 84 years']+age['Aged 85 years and over'])/age['All usual residents']).round(2)

# %%
age['middle_aged']=(1-(age['young_people']+age['children_teenager']+age['old_people'])).round(2)

# %%
age.head()
# Out:
#                  All usual residents  Aged 4 years and under  \
# ward name
# Abbey                          14225                    1121
# Abbey Road                     12980                     589
# Abbey Wood                     17417                    1147
# Abingdon                        8180                     356
# Addiscombe East                11794                     780
#
#                  Aged 5 to 9 years  Aged 10 to 14 years  Aged 15 to 19 years  \
# ward name
# Abbey                          948                  697                  512
# Abbey Road                     612                  669                  580
# Abbey Wood                    1394                 1475                 1114
# Abingdon                       343                  355                  279
# Addiscombe East                612                  620                  565
#
#                  Aged 20 to 24 years  Aged 25 to 29 years  \
# ward name
# Abbey                            728                 1649
# Abbey Road                       864                 1176
# Abbey Wood                      1029                 1283
# Abingdon                         736                  760
# Addiscombe East                  647                  833
#
#                  Aged 30 to 34 years  Aged 35 to 39 years  \
# ward name
# Abbey                           1826                 1624
# Abbey Road                      1345                 1092
# Abbey Wood                      1336                 1384
# Abingdon                         656                  630
# Addiscombe East                  976                  941
#
#                  Aged 40 to 44 years  ...  Aged 60 to 64 years  \
# ward name                             ...
# Abbey                           1299  ...                  453
# Abbey Road                      1004  ...                  561
# Abbey Wood                      1265  ...                  829
# Abingdon                         539  ...                  451
# Addiscombe East                  827  ...                  698
#
#                  Aged 65 to 69 years  Aged 70 to 74 years  \
# ward name
# Abbey                            328                  277
# Abbey Road                       474                  481
# Abbey Wood                       606                  415
# Abingdon                         328                  346
# Addiscombe East                  553                  510
#
#                  Aged 75 to 79 years  Aged 80 to 84 years  \
# ward name
# Abbey                            186                  104
# Abbey Road                       355                  279
# Abbey Wood                       315                  179
# Abingdon                         238                  141
# Addiscombe East                  304                  241
#
#                  Aged 85 years and over  young_people  children_teenager  \
# ward name
# Abbey                               122          0.09               0.19
# Abbey Road                          314          0.11               0.14
# Abbey Wood                          190          0.12               0.23
# Abingdon                            135          0.12               0.13
# Addiscombe East                     188          0.10               0.17
#
#                  old_people  middle_aged
# ward name
# Abbey                  0.07         0.65
# Abbey Road             0.15         0.60
# Abbey Wood             0.10         0.55
# Abingdon               0.15         0.60
# Addiscombe East        0.15         0.58
#
# [5 rows x 23 columns]

# %%
age = age.reset_index()

# %%
age
# Out:
#                 ward name  All usual residents  Aged 4 years and under  \
# 0                   Abbey                14225                    1121
# 1              Abbey Road                12980                     589
# 2              Abbey Wood                17417                    1147
# 3                Abingdon                 8180                     356
# 4         Addiscombe East                11794                     780
# ..                    ...                  ...                     ...
# 665  Worcester Park North                 8317                     566
# 666  Worcester Park South                 7167                     401
# 667              Wormholt                 7825                     402
# 668               Yeading                13564                    1045
# 669              Yiewsley                12115                    1163
#
#      Aged 5 to 9 years  Aged 10 to 14 years  Aged 15 to 19 years  \
# 0                  948                  697                  512
# 1                  612                  669                  580
# 2                 1394                 1475                 1114
# 3                  343                  355                  279
# 4                  612                  620                  565
# ..                 ...                  ...                  ...
# 665                616                  617                  454
# 666                474                  419                  336
# 667                408                  542                  516
# 668               1092                 1078                  870
# 669                878                  770                  690
#
#      Aged 20 to 24 years  Aged 25 to 29 years  Aged 30 to 34 years  \
# 0                    728                 1649                 1826
# 1                    864                 1176                 1345
# 2                   1029                 1283                 1336
# 3                    736                  760                  656
# 4                    647                  833                  976
# ..                   ...                  ...                  ...
# 665                  386                  407                  595
# 666                  331                  328                  375
# 667                  765                  836                  697
# 668                  772                  903                 1113
# 669                  761                 1033                 1209
#
#      Aged 35 to 39 years  ...  Aged 60 to 64 years  Aged 65 to 69 years  \
# 0                   1624  ...                  453                  328
# 1                   1092  ...                  561                  474
# 2                   1384  ...                  829                  606
# 3                    630  ...                  451                  328
# 4                    941  ...                  698                  553
# ..                   ...  ...                  ...                  ...
# 665                  730  ...                  360                  297
# 666                  470  ...                  475                  341
# 667                  553  ...                  350                  241
# 668                 1108  ...                  566                  390
# 669                 1130  ...                  456                  302
#
#      Aged 70 to 74 years  Aged 75 to 79 years  Aged 80 to 84 years  \
# 0                    277                  186                  104
# 1                    481                  355                  279
# 2                    415                  315                  179
# 3                    346                  238                  141
# 4                    510                  304                  241
# ..                   ...                  ...                  ...
# 665                  254                  212                  127
# 666                  433                  257                  215
# 667                  222                  130                  107
# 668                  312                  200                  146
# 669                  304                  188                  105
#
#      Aged 85 years and over  young_people  children_teenager  old_people  \
# 0                       122          0.09               0.19        0.07
# 1                       314          0.11               0.14        0.15
# 2                       190          0.12               0.23        0.10
# 3                       135          0.12               0.13        0.15
# 4                       188          0.10               0.17        0.15
# ..                      ...           ...                ...         ...
# 665                     110          0.10               0.22        0.12
# 666                     256          0.09               0.18        0.21
# 667                     106          0.16               0.17        0.10
# 668                     144          0.12               0.24        0.09
# 669                      96          0.12               0.23        0.08
#
#      middle_aged
# 0           0.65
# 1           0.60
# 2           0.55
# 3           0.60
# 4           0.58
# ..           ...
# 665         0.56
# 666         0.52
# 667         0.57
# 668         0.55
# 669         0.57
#
# [670 rows x 24 columns]

# %% [markdown]
# # deprivation

# %%
src_url   = 'https://data.london.gov.uk/download/2021-census-wards-demography-and-migration/05b99a3e-7e9a-467d-8d73-8417ee42bc9f/Household%20deprivation.xlsx'
dest_path = os.path.join('data','ward_socioeconomic')

household_deprivation = pd.read_excel(
    cache_data(src_url, dest_path), 
    sheet_name='2021')
# Out:
# Found data/ward_socioeconomic/Household%20deprivation.xlsx locally!

# %%
# Dropping the specified columns
household_deprivation = household_deprivation.drop(columns=['ward code', 'local authority code', 'local authority name'])
household_deprivation=household_deprivation.groupby('ward name').sum()
household_deprivation.head()
# Out:
#                  All Households  deprived in: no dimensions  1 dimension  \
# ward name
# Abbey                      5796                        3217         1757
# Abbey Road                 6062                        3425         1786
# Abbey Wood                 6207                        2432         2239
# Abingdon                   3893                        2276         1171
# Addiscombe East            4796                        2391         1612
#
#                  2 dimensions  3 dimensions  4 dimensions
# ward name
# Abbey                     650           157            15
# Abbey Road                594           235            22
# Abbey Wood               1116           374            46
# Abingdon                  324           106            16
# Addiscombe East           629           144            20

# %%
household_deprivation['household_deprivation_rate']=((household_deprivation['All Households']-household_deprivation['deprived in: no dimensions'])/household_deprivation['All Households']).round(2)

# %%
household_deprivation.sample(5)
# Out:
#                               All Households  deprived in: no dimensions  \
# ward name
# Wealdstone South                        2623                        1037
# Colham & Cowley                         6627                        2675
# Brimsdown                               5606                        1979
# Kenton East                             4491                        1867
# Charlton Village & Riverside            3969                        1666
#
#                               1 dimension  2 dimensions  3 dimensions  \
# ward name
# Wealdstone South                      965           471           134
# Colham & Cowley                      2455          1144           321
# Brimsdown                            2104          1119           362
# Kenton East                          1730           720           163
# Charlton Village & Riverside         1355           688           245
#
#                               4 dimensions  household_deprivation_rate
# ward name
# Wealdstone South                        16                        0.60
# Colham & Cowley                         32                        0.60
# Brimsdown                               42                        0.65
# Kenton East                             11                        0.58
# Charlton Village & Riverside            15                        0.58

# %%
household_deprivation = household_deprivation.reset_index()

# %% [markdown]
# # economiaclly active total 不需要

# %%
src_url   = 'https://data.london.gov.uk/download/2021-census-wards-labour-market/6030ee1e-7f1f-47ca-9175-b30a12fe5b0c/Economic%20Activity.xlsx'
dest_path = os.path.join('data','ward_socioeconomic')

economic_activity = pd.read_excel(
    cache_data(src_url, dest_path), 
    sheet_name='2021')
# Out:
# Found data/ward_socioeconomic/Economic%20Activity.xlsx locally!

# %%
economic_activity.head()
# Out:
#    ward code          ward name local authority code  local authority name  \
# 0  E09000001     City of London            E09000001        City of London
# 1  E05014053              Abbey            E09000002  Barking and Dagenham
# 2  E05014054             Alibon            E09000002  Barking and Dagenham
# 3  E05014055  Barking Riverside            E09000002  Barking and Dagenham
# 4  E05014056               Beam            E09000002  Barking and Dagenham
#
#    All usual residents aged 16+  Economically active Total  \
# 0                          8014                       5677
# 1                          2952                       2045
# 2                          7458                       4867
# 3                          6903                       4970
# 4                          6080                       3901
#
#    Employee; Part time  Employee; Full time  \
# 0                  441                 3761
# 1                  315                 1099
# 2                  926                 2331
# 3                  961                 2625
# 4                  841                 1803
#
#    Self employed with employees Part time  \
# 0                                      28
# 1                                      21
# 2                                      31
# 3                                      39
# 4                                      37
#
#    Self employed with employees Full time  \
# 0                                     149
# 1                                      51
# 2                                     106
# 3                                      75
# 4                                      98
#
#    Self employed without employees Part time  \
# 0                                        365
# 1                                         86
# 2                                        285
# 3                                        242
# 4                                        222
#
#    Self employed without employees Full time  Unemployed  \
# 0                                        520         283
# 1                                        195         143
# 2                                        567         339
# 3                                        393         361
# 4                                        368         296
#
#    Economically active Full time student  Economically inactive Total  \
# 0                                    130                         2337
# 1                                    135                          907
# 2                                    282                         2591
# 3                                    274                         1933
# 4                                    236                         2179
#
#    Economically inactive: retired  Economically inactive full time students  \
# 0                             993                                       723
# 1                             149                                       168
# 2                             863                                       534
# 3                             275                                       555
# 4                             697                                       492
#
#    Looking after home or family  Long term sick or disabled  \
# 0                           195                         123
# 1                           313                         116
# 2                           545                         294
# 3                           578                         250
# 4                           462                         237
#
#    Economically inactive: other
# 0                           303
# 1                           161
# 2                           355
# 3                           275
# 4                           291

# %% [markdown]
# # creat whole dataset

# %%
neighbor_socioeconomic=status[['ward name','nonwork_rate','middle_high_class_pro','advanced_education_rate']]

# %%
neighbor_socioeconomic.head()
# Out:
#          ward name  nonwork_rate  middle_high_class_pro  \
# 0            Abbey          0.08                   0.57
# 1       Abbey Road          0.11                   0.59
# 2       Abbey Wood          0.13                   0.35
# 3         Abingdon          0.10                   0.57
# 4  Addiscombe East          0.08                   0.53
#
#    advanced_education_rate
# 0                     0.07
# 1                     0.11
# 2                     0.10
# 3                     0.13
# 4                     0.07

# %%
common_key='ward name'

# add every column into the first dataset
neighbor_socioeconomic = neighbor_socioeconomic.merge(method_of_work[[common_key, 'public_transport_station_coverage']], on=common_key, how='left')
neighbor_socioeconomic = neighbor_socioeconomic.merge(commute_distance[[common_key, 'average_commute_distance']], on=common_key, how='left')
neighbor_socioeconomic = neighbor_socioeconomic.merge(health[[common_key, 'All Usual residents','unhealthy_rate']], on=common_key, how='left')
neighbor_socioeconomic = neighbor_socioeconomic.merge(disability[[common_key, 'disabled_pro']], on=common_key, how='left')

neighbor_socioeconomic = neighbor_socioeconomic.merge(houseprice_2022[[common_key, 'median_houseprice_2022']], on=common_key, how='left')
neighbor_socioeconomic = neighbor_socioeconomic.merge(house_rent_price[[common_key, 'mean_rent_price']], on=common_key, how='left')
neighbor_socioeconomic = neighbor_socioeconomic.merge(crime_2023[[common_key, 'average_crime']], on=common_key, how='left')
neighbor_socioeconomic = neighbor_socioeconomic.merge(age[[common_key, 'young_people','children_teenager','old_people','middle_aged']], on=common_key, how='left')
neighbor_socioeconomic = neighbor_socioeconomic.merge(household_deprivation[[common_key, 'household_deprivation_rate']], on=common_key, how='left')

# %%
neighbor_socioeconomic.head()
# Out:
#          ward name  nonwork_rate  middle_high_class_pro  \
# 0            Abbey          0.08                   0.57
# 1       Abbey Road          0.11                   0.59
# 2       Abbey Wood          0.13                   0.35
# 3         Abingdon          0.10                   0.57
# 4  Addiscombe East          0.08                   0.53
#
#    advanced_education_rate  public_transport_station_coverage  \
# 0                     0.07                               0.54
# 1                     0.11                               0.44
# 2                     0.10                               0.49
# 3                     0.13                               0.41
# 4                     0.07                               0.40
#
#    average_commute_distance  All Usual residents  unhealthy_rate  \
# 0                      3.86                14229            0.03
# 1                      2.01                12977            0.04
# 2                      6.37                17425            0.05
# 3                      1.95                 8158            0.03
# 4                      4.36                11802            0.04
#
#    disabled_pro  median_houseprice_2022  mean_rent_price  average_crime  \
# 0          0.10                976600.0          2563.59         365.09
# 1          0.11                     NaN          1387.90         121.64
# 2          0.15                385000.0          1217.33         238.00
# 3          0.10               1435000.0          1400.00         142.00
# 4          0.14                441000.0          1357.98         133.64
#
#    young_people  children_teenager  old_people  middle_aged  \
# 0          0.09               0.19        0.07         0.65
# 1          0.11               0.14        0.15         0.60
# 2          0.12               0.23        0.10         0.55
# 3          0.12               0.13        0.15         0.60
# 4          0.10               0.17        0.15         0.58
#
#    household_deprivation_rate
# 0                        0.44
# 1                        0.44
# 2                        0.61
# 3                        0.42
# 4                        0.50

# %%
neighbor_socioeconomic.to_excel('Neighbourdata_Cleaned.xlsx')

# %% [markdown]
# # zhi biao
# commute_distance["average_commute_distance"] 2
#
# health['unhealthy_rate']3 4
#
# disability['disabled_pro']5
#
# houseprice_2022['median_houseprice_2022']6
#
# house_rent_price['mean_rent_price'] 7
#
# crime_sum_ward = crime_sum_2023.groupby('WardName')['avarge_crime'] 8
#
# young_people	children_teenager	old_people	middle_aged 12
#
# household_deprivation['household_deprivation_rate'] 13

# %%
#read airbnb data
airbnb_file = 'airbnb_ward_clean.csv'
airbnb_data = pd.read_csv(airbnb_file)

# %%
airbnb_data.head()
# Out:
#    Unnamed: 0           WD22NM  total_room  Entire home/apt  Hotel room  \
# 0           0            Abbey         170            110.0         0.0
# 1           1       Abbey Road         195            152.0         0.0
# 2           2       Abbey Wood          85             37.0         0.0
# 3           3         Abingdon         278            227.0         0.0
# 4           4  Addiscombe East          33             13.0         0.0
#
#    Private room  Shared room   avg_price  avg_minimum_nights  \
# 0          60.0          0.0  146.958824            3.670588
# 1          43.0          0.0  183.897436            5.287179
# 2          48.0          0.0   87.376471            4.176471
# 3          51.0          0.0  220.147482            4.521583
# 4          20.0          0.0   80.393939            3.363636
#
#    avg_reviews_per_month  avg_availability_365  avg_star_rate
# 0               0.843016            131.158824       4.670460
# 1               1.362932            128.512821       4.677921
# 2               0.822787            228.435294       4.650213
# 3               0.874352            150.741007       4.572039
# 4               1.234800            113.848485       4.737778

# %%
# Rename the column in Airbnb data to match the Neighbourhood data
airbnb_data = airbnb_data.rename(columns={"WD22NM": "ward name"})

# Merge the two datasets on 'ward name'
merged_data = pd.merge(airbnb_data_renamed, neighbor_socioeconomic, on="ward name", how="left")

# Display the first few rows of the merged dataframe
merged_data.head()
# Out:
#    Unnamed: 0        ward name  total_room  Entire home/apt  Hotel room  \
# 0           0            Abbey         170            110.0         0.0
# 1           1       Abbey Road         195            152.0         0.0
# 2           2       Abbey Wood          85             37.0         0.0
# 3           3         Abingdon         278            227.0         0.0
# 4           4  Addiscombe East          33             13.0         0.0
#
#    Private room  Shared room   avg_price  avg_minimum_nights  \
# 0          60.0          0.0  146.958824            3.670588
# 1          43.0          0.0  183.897436            5.287179
# 2          48.0          0.0   87.376471            4.176471
# 3          51.0          0.0  220.147482            4.521583
# 4          20.0          0.0   80.393939            3.363636
#
#    avg_reviews_per_month  ...  unhealthy_rate  disabled_pro  \
# 0               0.843016  ...            0.03          0.10
# 1               1.362932  ...            0.04          0.11
# 2               0.822787  ...            0.05          0.15
# 3               0.874352  ...            0.03          0.10
# 4               1.234800  ...            0.04          0.14
#
#    median_houseprice_2022  mean_rent_price  average_crime  young_people  \
# 0                976600.0          2563.59         365.09          0.09
# 1                     NaN          1387.90         121.64          0.11
# 2                385000.0          1217.33         238.00          0.12
# 3               1435000.0          1400.00         142.00          0.12
# 4                441000.0          1357.98         133.64          0.10
#
#    children_teenager  old_people  middle_aged  household_deprivation_rate
# 0               0.19        0.07         0.65                        0.44
# 1               0.14        0.15         0.60                        0.44
# 2               0.23        0.10         0.55                        0.61
# 3               0.13        0.15         0.60                        0.42
# 4               0.17        0.15         0.58                        0.50
#
# [5 rows x 28 columns]

# %%
merged_data.to_excel('Airbnb_Merged.xlsx')
