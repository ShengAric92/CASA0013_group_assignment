# %%
#load libraries
import pandas as pd
import re

# %%
import os
from requests import get
from urllib.parse import urlparse

def cache_data(src:str, dest:str) -> str:
    """Downloads and caches a remote file locally.
    
    The function sits between the 'read' step of a pandas or geopandas
    data frame and downloading the file from a remote location. The idea
    is that it will save it locally so that you don't need to remember to
    do so yourself. Subsequent re-reads of the file will return instantly
    rather than downloading the entire file for a second or n-th itme.
    
    Parameters
    ----------
    src : str
        The remote *source* for the file, any valid URL should work.
    dest : str
        The *destination* location to save the downloaded file.
        
    Returns
    -------
    str
        A string representing the local location of the file.
    """
    
    url = urlparse(src) # We assume that this is some kind of valid URL 
    fn  = os.path.split(url.path)[-1] # Extract the filename
    dfn = os.path.join(dest,fn) # Destination filename
    
    # Check if dest+filename does *not* exist -- 
    # that would mean we have to download it!
    if not os.path.isfile(dfn):
        
        print(f"{dfn} not found, downloading!")

        # Convert the path back into a list (without)
        # the filename -- we need to check that directories
        # exist first.
        path = os.path.split(dest)
        
        # Create any missing directories in dest(ination) path
        # -- os.path.join is the reverse of split (as you saw above)
        # but it doesn't work with lists... so I had to google how
        # to use the 'splat' operator! os.makedirs creates missing
        # directories in a path automatically.
        if len(path) >= 1 and path[0] != '':
            os.makedirs(os.path.join(*path), exist_ok=True)
            
        # Download and write the file
        with open(dfn, "wb") as file:
            response = get(src)
            file.write(response.content)
            
        print('Done downloading...')

    else:
        print(f"Found {dfn} locally!")

    return dfn

# %% [markdown]
# # socioeconomic data tidying

# %% [markdown]
# ## nowork_rate、middle_high_class_pro、advanced_education_rate indictors

# %%
src_url   = 'https://data.london.gov.uk/download/2021-census-wards-labour-market/ab2e314e-dbd8-4afe-8304-1f5402eda542/NSSEC.xlsx'
dest_path = os.path.join('data','ward_socioeconomic')

status = pd.read_excel(
    cache_data(src_url, dest_path), 
    sheet_name='2021')
# Out:
# Found data/ward_socioeconomic/NSSEC.xlsx locally!

# %%
status.head()
# Out:
#    ward code          ward name local authority code  local authority name  \
# 0  E09000001     City of London            E09000001        City of London
# 1  E05014053              Abbey            E09000002  Barking and Dagenham
# 2  E05014054             Alibon            E09000002  Barking and Dagenham
# 3  E05014055  Barking Riverside            E09000002  Barking and Dagenham
# 4  E05014056               Beam            E09000002  Barking and Dagenham
#
#    All usual residents aged 16+   Higher managerial admin and professional   \
# 0                           8003                                       3173
# 1                           2940                                        455
# 2                           7458                                        419
# 3                           6901                                        680
# 4                           6092                                        305
#
#    Lower managerial admin and professional   Intermediate   \
# 0                                      1914            431
# 1                                       481            228
# 2                                      1139            769
# 3                                      1271            736
# 4                                       873            654
#
#    Small employers, own account workers  Lower supervisory and technical   \
# 0                                   571                               133
# 1                                   358                               107
# 2                                  1044                               414
# 3                                   757                               341
# 4                                   783                               320
#
#    Semi routine  Routine   Never worked and long term unemployed  \
# 0           289       257                                    441
# 1           299       308                                    415
# 2           964      1039                                    893
# 3           743       785                                    785
# 4           791       893                                    764
#
#    Full time students
# 0                 794
# 1                 289
# 2                 777
# 3                 803
# 4                 709

# %%
status.columns.to_list()
# Out:
# ['ward code',
#  'ward name',
#  'local authority code',
#  'local authority name',
#  'All usual residents aged 16+ ',
#  'Higher managerial admin and professional ',
#  'Lower managerial admin and professional ',
#  'Intermediate ',
#  'Small employers, own account workers',
#  'Lower supervisory and technical ',
#  'Semi routine',
#  'Routine ',
#  'Never worked and long term unemployed',
#  'Full time students']

# %%
# Dropping the specified columns
status = status.drop(columns=['local authority code', 'local authority name'])
status.head()
# Out:
#    ward code          ward name  All usual residents aged 16+   \
# 0  E09000001     City of London                           8003
# 1  E05014053              Abbey                           2940
# 2  E05014054             Alibon                           7458
# 3  E05014055  Barking Riverside                           6901
# 4  E05014056               Beam                           6092
#
#    Higher managerial admin and professional   \
# 0                                       3173
# 1                                        455
# 2                                        419
# 3                                        680
# 4                                        305
#
#    Lower managerial admin and professional   Intermediate   \
# 0                                      1914            431
# 1                                       481            228
# 2                                      1139            769
# 3                                      1271            736
# 4                                       873            654
#
#    Small employers, own account workers  Lower supervisory and technical   \
# 0                                   571                               133
# 1                                   358                               107
# 2                                  1044                               414
# 3                                   757                               341
# 4                                   783                               320
#
#    Semi routine  Routine   Never worked and long term unemployed  \
# 0           289       257                                    441
# 1           299       308                                    415
# 2           964      1039                                    893
# 3           743       785                                    785
# 4           791       893                                    764
#
#    Full time students
# 0                 794
# 1                 289
# 2                 777
# 3                 803
# 4                 709

# %%
status=status.groupby('ward code').sum()

# %%
#add no_work_people_rate column and no_work_people_rate=Never worked and long term unemployed  
status['nonwork_rate'] = (status['Never worked and long term unemployed']/status["All usual residents aged 16+ "]).round(2)
#add proportion of middle and high class population 
status['middle_high_class_pro'] = ((status['Higher managerial admin and professional '] + status['Lower managerial admin and professional '] + status['Intermediate '])/status["All usual residents aged 16+ "]).round(2)
#add proportion of higher education
status['advanced_education_rate'] = (status['Full time students']/status["All usual residents aged 16+ "]).round(2)

# %%
status.head()
# Out:
#                          ward name  All usual residents aged 16+   \
# ward code
# E05009317            Bethnal Green                          17109
# E05009318  Blackwall & Cubitt Town                          18518
# E05009319                 Bow East                          16311
# E05009320                 Bow West                          11331
# E05009321            Bromley North                           9015
#
#            Higher managerial admin and professional   \
# ward code
# E05009317                                       2607
# E05009318                                       5891
# E05009319                                       3621
# E05009320                                       2199
# E05009321                                       1249
#
#            Lower managerial admin and professional   Intermediate   \
# ward code
# E05009317                                      3056           1363
# E05009318                                      3608           1293
# E05009319                                      3849           1314
# E05009320                                      2562            948
# E05009321                                      1645            804
#
#            Small employers, own account workers  \
# ward code
# E05009317                                  1207
# E05009318                                  1204
# E05009319                                  1202
# E05009320                                   931
# E05009321                                   677
#
#            Lower supervisory and technical   Semi routine  Routine   \
# ward code
# E05009317                               663          1422      1299
# E05009318                               514          1020       859
# E05009319                               547          1196      1246
# E05009320                               433           865       984
# E05009321                               366           889       795
#
#            Never worked and long term unemployed  Full time students  \
# ward code
# E05009317                                   2314                3178
# E05009318                                   1678                2451
# E05009319                                   1875                1461
# E05009320                                   1275                1134
# E05009321                                   1554                1036
#
#            nonwork_rate  middle_high_class_pro  advanced_education_rate
# ward code
# E05009317          0.14                   0.41                     0.19
# E05009318          0.09                   0.58                     0.13
# E05009319          0.11                   0.54                     0.09
# E05009320          0.11                   0.50                     0.10
# E05009321          0.17                   0.41                     0.11

# %%
status = status.reset_index()
status
# Out:
#      ward code                ward name  All usual residents aged 16+   \
# 0    E05009317            Bethnal Green                          17109
# 1    E05009318  Blackwall & Cubitt Town                          18518
# 2    E05009319                 Bow East                          16311
# 3    E05009320                 Bow West                          11331
# 4    E05009321            Bromley North                           9015
# ..         ...                      ...                            ...
# 675  E05014116          Streatham Wells                           8229
# 676  E05014117                 Vauxhall                           8602
# 677  E05014118    Waterloo & South Bank                           8012
# 678  E05014119             West Dulwich                           9269
# 679  E09000001           City of London                           8003
#
#      Higher managerial admin and professional   \
# 0                                         2607
# 1                                         5891
# 2                                         3621
# 3                                         2199
# 4                                         1249
# ..                                         ...
# 675                                       1647
# 676                                       2173
# 677                                       1708
# 678                                       2441
# 679                                       3173
#
#      Lower managerial admin and professional   Intermediate   \
# 0                                        3056           1363
# 1                                        3608           1293
# 2                                        3849           1314
# 3                                        2562            948
# 4                                        1645            804
# ..                                        ...            ...
# 675                                      2067            747
# 676                                      1792            588
# 677                                      1475            526
# 678                                      2453            778
# 679                                      1914            431
#
#      Small employers, own account workers  Lower supervisory and technical   \
# 0                                    1207                               663
# 1                                    1204                               514
# 2                                    1202                               547
# 3                                     931                               433
# 4                                     677                               366
# ..                                    ...                               ...
# 675                                   889                               329
# 676                                   671                               224
# 677                                   501                               241
# 678                                   905                               274
# 679                                   571                               133
#
#      Semi routine  Routine   Never worked and long term unemployed  \
# 0            1422      1299                                   2314
# 1            1020       859                                   1678
# 2            1196      1246                                   1875
# 3             865       984                                   1275
# 4             889       795                                   1554
# ..            ...       ...                                    ...
# 675           646       679                                    701
# 676           514       583                                    590
# 677           478       545                                    536
# 678           572       595                                    657
# 679           289       257                                    441
#
#      Full time students  nonwork_rate  middle_high_class_pro  \
# 0                  3178          0.14                   0.41
# 1                  2451          0.09                   0.58
# 2                  1461          0.11                   0.54
# 3                  1134          0.11                   0.50
# 4                  1036          0.17                   0.41
# ..                  ...           ...                    ...
# 675                 524          0.09                   0.54
# 676                1467          0.07                   0.53
# 677                2002          0.07                   0.46
# 678                 594          0.07                   0.61
# 679                 794          0.06                   0.69
#
#      advanced_education_rate
# 0                       0.19
# 1                       0.13
# 2                       0.09
# 3                       0.10
# 4                       0.11
# ..                       ...
# 675                     0.06
# 676                     0.17
# 677                     0.25
# 678                     0.06
# 679                     0.10
#
# [680 rows x 15 columns]

# %% [markdown]
# ## public_transport_station_coverage

# %%
# download data
src_url   = 'https://data.london.gov.uk/download/2021-census-wards-labour-market/d9f01451-3960-4a1f-a43d-392e45aa0830/Method%20of%20travel%20to%20work.xlsx'
dest_path = os.path.join('data','ward_socioeconomic')

method_of_work = pd.read_excel(
    cache_data(src_url, dest_path), 
    sheet_name='2021')
# Out:
# Found data/ward_socioeconomic/Method%20of%20travel%20to%20work.xlsx locally!

# %%
# check the column names
method_of_work.columns.to_list()
# Out:
# ['ward code',
#  'ward name',
#  'local authority code',
#  'local authority name',
#  'All usual residents aged 16+ in employment',
#  'Work mainly at or from home',
#  'Under-ground; metro; light rail; tram',
#  'Train',
#  'Bus; minibus or coach',
#  'Taxi',
#  'Motorcycle; scooter or moped',
#  'Driving a car or van',
#  'Passenger in a car or van',
#  'Bicycle',
#  'On foot',
#  'Other method of travel to work']

# %%
# Dropping the specified columns
method_of_work = method_of_work.drop(columns=['local authority code', 'local authority name'])
method_of_work=method_of_work.groupby('ward code').sum()
method_of_work.head()
# Out:
#                          ward name  \
# ward code
# E05009317            Bethnal Green
# E05009318  Blackwall & Cubitt Town
# E05009319                 Bow East
# E05009320                 Bow West
# E05009321            Bromley North
#
#            All usual residents aged 16+ in employment  \
# ward code
# E05009317                                        9653
# E05009318                                       12792
# E05009319                                       10861
# E05009320                                        7265
# E05009321                                        5264
#
#            Work mainly at or from home  Under-ground; metro; light rail; tram  \
# ward code
# E05009317                         4273                                   1290
# E05009318                         7803                                   1913
# E05009319                         5917                                   1308
# E05009320                         3598                                    929
# E05009321                         2078                                    983
#
#            Train  Bus; minibus or coach  Taxi  Motorcycle; scooter or moped  \
# ward code
# E05009317    444                    699    42                            56
# E05009318    479                    384    52                            35
# E05009319    363                    657    78                            52
# E05009320    255                    478    43                            32
# E05009321    373                    433    33                            33
#
#            Driving a car or van  Passenger in a car or van  Bicycle  On foot  \
# ward code
# E05009317                  1006                         79      622     1030
# E05009318                   876                         66      274      799
# E05009319                   928                         57      759      650
# E05009320                   706                         55      559      509
# E05009321                   622                         41      240      359
#
#            Other method of travel to work
# ward code
# E05009317                             112
# E05009318                             111
# E05009319                              92
# E05009320                             101
# E05009321                              69

# %%
#select a representive indicator to analyse. 
#we want to find the quantity of public transportation around places where people live, 
#so we decide to choose "Under-ground; metro; light rail; tram","Bus; minibus or coach","Train" columns to represent.
method_of_work["public_transport_station_coverage"] = ((method_of_work["Under-ground; metro; light rail; tram"]+method_of_work["Train"]+method_of_work["Bus; minibus or coach"])/(method_of_work["All usual residents aged 16+ in employment"]-method_of_work["Work mainly at or from home"])).round(2)
method_of_work.head()
# Out:
#                          ward name  \
# ward code
# E05009317            Bethnal Green
# E05009318  Blackwall & Cubitt Town
# E05009319                 Bow East
# E05009320                 Bow West
# E05009321            Bromley North
#
#            All usual residents aged 16+ in employment  \
# ward code
# E05009317                                        9653
# E05009318                                       12792
# E05009319                                       10861
# E05009320                                        7265
# E05009321                                        5264
#
#            Work mainly at or from home  Under-ground; metro; light rail; tram  \
# ward code
# E05009317                         4273                                   1290
# E05009318                         7803                                   1913
# E05009319                         5917                                   1308
# E05009320                         3598                                    929
# E05009321                         2078                                    983
#
#            Train  Bus; minibus or coach  Taxi  Motorcycle; scooter or moped  \
# ward code
# E05009317    444                    699    42                            56
# E05009318    479                    384    52                            35
# E05009319    363                    657    78                            52
# E05009320    255                    478    43                            32
# E05009321    373                    433    33                            33
#
#            Driving a car or van  Passenger in a car or van  Bicycle  On foot  \
# ward code
# E05009317                  1006                         79      622     1030
# E05009318                   876                         66      274      799
# E05009319                   928                         57      759      650
# E05009320                   706                         55      559      509
# E05009321                   622                         41      240      359
#
#            Other method of travel to work  public_transport_station_coverage
# ward code
# E05009317                             112                               0.45
# E05009318                             111                               0.56
# E05009319                              92                               0.47
# E05009320                             101                               0.45
# E05009321                              69                               0.56

# %%
#change ward name to merge other indicators
method_of_work.rename(columns={'Ward name': 'ward name'}, inplace=True)

# %%
method_of_work
# Out:
#                          ward name  \
# ward code
# E05009317            Bethnal Green
# E05009318  Blackwall & Cubitt Town
# E05009319                 Bow East
# E05009320                 Bow West
# E05009321            Bromley North
# ...                            ...
# E05014116          Streatham Wells
# E05014117                 Vauxhall
# E05014118    Waterloo & South Bank
# E05014119             West Dulwich
# E09000001           City of London
#
#            All usual residents aged 16+ in employment  \
# ward code
# E05009317                                        9653
# E05009318                                       12792
# E05009319                                       10861
# E05009320                                        7265
# E05009321                                        5264
# ...                                               ...
# E05014116                                        5688
# E05014117                                        5516
# E05014118                                        4425
# E05014119                                        6237
# E09000001                                        5358
#
#            Work mainly at or from home  Under-ground; metro; light rail; tram  \
# ward code
# E05009317                         4273                                   1290
# E05009318                         7803                                   1913
# E05009319                         5917                                   1308
# E05009320                         3598                                    929
# E05009321                         2078                                    983
# ...                                ...                                    ...
# E05014116                         2719                                    437
# E05014117                         3077                                    582
# E05014118                         2268                                    416
# E05014119                         3549                                    313
# E09000001                         3611                                    346
#
#            Train  Bus; minibus or coach  Taxi  Motorcycle; scooter or moped  \
# ward code
# E05009317    444                    699    42                            56
# E05009318    479                    384    52                            35
# E05009319    363                    657    78                            52
# E05009320    255                    478    43                            32
# E05009321    373                    433    33                            33
# ...          ...                    ...   ...                           ...
# E05014116    309                    748    20                            75
# E05014117    225                    437    41                            30
# E05014118    167                    395    37                            27
# E05014119    441                    477    24                            40
# E09000001     97                    134    20                            12
#
#            Driving a car or van  Passenger in a car or van  Bicycle  On foot  \
# ward code
# E05009317                  1006                         79      622     1030
# E05009318                   876                         66      274      799
# E05009319                   928                         57      759      650
# E05009320                   706                         55      559      509
# E05009321                   622                         41      240      359
# ...                         ...                        ...      ...      ...
# E05014116                   723                         48      252      289
# E05014117                   282                         24      279      466
# E05014118                   242                         25      227      570
# E05014119                   673                         30      335      307
# E09000001                   123                         12      191      760
#
#            Other method of travel to work  public_transport_station_coverage
# ward code
# E05009317                             112                               0.45
# E05009318                             111                               0.56
# E05009319                              92                               0.47
# E05009320                             101                               0.45
# E05009321                              69                               0.56
# ...                                   ...                                ...
# E05014116                              68                               0.50
# E05014117                              73                               0.51
# E05014118                              51                               0.45
# E05014119                              48                               0.46
# E09000001                              52                               0.33
#
# [680 rows x 14 columns]

# %%
method_of_work = method_of_work.reset_index()

# %% [markdown]
# ## commute_distance

# %%
# download data
src_url   = ' https://data.london.gov.uk/download/2021-census-wards-labour-market/7725cc70-ab2b-4674-99cb-b825bc9ef4ca/Distance%20traveled%20to%20work.xlsx'
dest_path = os.path.join('data','ward_socioeconomic')

commute_distance = pd.read_excel(
    cache_data(src_url, dest_path), 
    sheet_name='2021')
# Out:
# Found data/ward_socioeconomic/Distance%20traveled%20to%20work.xlsx locally!

# %%
# check columns
commute_distance.columns.to_list()
# Out:
# ['ward code',
#  'ward name',
#  'local authority code',
#  'local authority name',
#  'All usual residents aged 16+ in employment',
#  'Less than 2km',
#  '2km to less than 5km',
#  '5km to less than 10km',
#  '10km to less than 20km',
#  '20km to less than 30km',
#  '30km to less than 40km',
#  '40km to less than 60km',
#  '60km and over',
#  'Works mainly from home',
#  'Other']

# %%
# Dropping the specified columns
commute_distance = commute_distance.drop(columns=['local authority code', 'local authority name'])
commute_distance=commute_distance.groupby('ward code').sum()
commute_distance.head()
# Out:
#                          ward name  \
# ward code
# E05009317            Bethnal Green
# E05009318  Blackwall & Cubitt Town
# E05009319                 Bow East
# E05009320                 Bow West
# E05009321            Bromley North
#
#            All usual residents aged 16+ in employment  Less than 2km  \
# ward code
# E05009317                                        9649           1087
# E05009318                                       12793            885
# E05009319                                       10880            630
# E05009320                                        7261            515
# E05009321                                        5263            433
#
#            2km to less than 5km  5km to less than 10km  \
# ward code
# E05009317                  1385                   1159
# E05009318                   754                   1553
# E05009319                  1305                   1376
# E05009320                  1096                    880
# E05009321                   824                    842
#
#            10km to less than 20km  20km to less than 30km  \
# ward code
# E05009317                     390                      82
# E05009318                     643                      89
# E05009319                     462                      48
# E05009320                     292                      55
# E05009321                     317                      51
#
#            30km to less than 40km  40km to less than 60km  60km and over  \
# ward code
# E05009317                      36                      54             79
# E05009318                      47                      53             61
# E05009319                      31                      35             52
# E05009320                      24                      21             48
# E05009321                      30                      28             34
#
#            Works mainly from home  Other
# ward code
# E05009317                    4273   1104
# E05009318                    7803    905
# E05009319                    5917   1024
# E05009320                    3598    732
# E05009321                    2078    626

# %%
# add average_commute_distance 
# average_commute_distance = sum of the total proportion of different commuting distances
commute_distance["average_commute_distance"] = ((commute_distance["Less than 2km"]*1+commute_distance["2km to less than 5km"]*3.5+commute_distance["5km to less than 10km"]*7.5+commute_distance["10km to less than 20km"]*15+commute_distance["20km to less than 30km"]*25+commute_distance["30km to less than 40km"]*35+commute_distance["40km to less than 60km"]*50+commute_distance["60km and over"]*60)/commute_distance["All usual residents aged 16+ in employment"]).round(2)

# %%
#reset index
commute_distance = commute_distance.reset_index()

# %%
commute_distance
# Out:
#      ward code                ward name  \
# 0    E05009317            Bethnal Green
# 1    E05009318  Blackwall & Cubitt Town
# 2    E05009319                 Bow East
# 3    E05009320                 Bow West
# 4    E05009321            Bromley North
# ..         ...                      ...
# 675  E05014116          Streatham Wells
# 676  E05014117                 Vauxhall
# 677  E05014118    Waterloo & South Bank
# 678  E05014119             West Dulwich
# 679  E09000001           City of London
#
#      All usual residents aged 16+ in employment  Less than 2km  \
# 0                                          9649           1087
# 1                                         12793            885
# 2                                         10880            630
# 3                                          7261            515
# 4                                          5263            433
# ..                                          ...            ...
# 675                                        5694            243
# 676                                        5506            391
# 677                                        4420            565
# 678                                        6247            279
# 679                                        5362            674
#
#      2km to less than 5km  5km to less than 10km  10km to less than 20km  \
# 0                    1385                   1159                     390
# 1                     754                   1553                     643
# 2                    1305                   1376                     462
# 3                    1096                    880                     292
# 4                     824                    842                     317
# ..                    ...                    ...                     ...
# 675                   518                    978                     398
# 676                   869                    393                     167
# 677                   554                    331                     154
# 678                   561                    942                     256
# 679                   384                    237                      86
#
#      20km to less than 30km  30km to less than 40km  40km to less than 60km  \
# 0                        82                      36                      54
# 1                        89                      47                      53
# 2                        48                      31                      35
# 3                        55                      24                      21
# 4                        51                      30                      28
# ..                      ...                     ...                     ...
# 675                      44                      17                      16
# 676                      35                      23                      10
# 677                      25                      13                      19
# 678                      28                       8                       8
# 679                      15                       7                       9
#
#      60km and over  Works mainly from home  Other  average_commute_distance
# 0               79                    4273   1104                      3.24
# 1               61                    7803    905                      2.74
# 2               52                    5917   1024                      2.72
# 3               48                    3598    732                      2.96
# 4               34                    2078    626                      3.83
# ..             ...                     ...    ...                       ...
# 675             29                    2719    732                      3.44
# 676             27                    3077    514                      2.30
# 677             22                    2268    469                      2.41
# 678             32                    3549    584                      2.63
# 679             30                    3611    309                      1.48
#
# [680 rows x 14 columns]

# %% [markdown]
# ## uhealthy_rate、usual_residents

# %%
# download data
src_url   = 'https://data.london.gov.uk/download/2021-census-wards-qualifications-health-disability-and-care/af5f35f0-fdd3-4531-9616-ff1f1a64101a/General%20health.xlsx'
dest_path = os.path.join('data','ward_socioeconomic')

health = pd.read_excel(
    cache_data(src_url, dest_path), 
    sheet_name='2021')
# Out:
# Found data/ward_socioeconomic/General%20health.xlsx locally!

# %%
# check column name
health.columns.to_list()
# Out:
# ['ward code',
#  'ward name',
#  'local authority code',
#  'local authority name',
#  'All Usual residents ',
#  'Very good health',
#  'Good health',
#  'Fair health',
#  'Bad health',
#  'Very bad health']

# %%
# Dropping the specified columns
health = health.drop(columns=['local authority code', 'local authority name'])
health=health.groupby('ward code').sum()
health.head()
# Out:
#                          ward name  All Usual residents   Very good health  \
# ward code
# E05009317            Bethnal Green                 21219             11024
# E05009318  Blackwall & Cubitt Town                 21823             12609
# E05009319                 Bow East                 19535             10495
# E05009320                 Bow West                 13713              7246
# E05009321            Bromley North                 11436              5596
#
#            Good health  Fair health  Bad health  Very bad health
# ward code
# E05009317         6891         2194         843              267
# E05009318         6931         1633         483              167
# E05009319         6152         1931         692              265
# E05009320         4279         1450         552              186
# E05009321         3854         1340         462              184

# %%
#i think bad health rate can be representaive
#add unhealtht_rate column
health['unhealthy_rate']=((health['Bad health']+health['Very bad health'])/health['All Usual residents ']).round(2)

# %%
health.rename(columns={'All Usual residents ': 'All Usual residents'}, inplace=True)

# %%
health.head()
# Out:
#                          ward name  All Usual residents  Very good health  \
# ward code
# E05009317            Bethnal Green                21219             11024
# E05009318  Blackwall & Cubitt Town                21823             12609
# E05009319                 Bow East                19535             10495
# E05009320                 Bow West                13713              7246
# E05009321            Bromley North                11436              5596
#
#            Good health  Fair health  Bad health  Very bad health  \
# ward code
# E05009317         6891         2194         843              267
# E05009318         6931         1633         483              167
# E05009319         6152         1931         692              265
# E05009320         4279         1450         552              186
# E05009321         3854         1340         462              184
#
#            unhealthy_rate
# ward code
# E05009317            0.05
# E05009318            0.03
# E05009319            0.05
# E05009320            0.05
# E05009321            0.06

# %%
health = health.reset_index()

# %% [markdown]
# ## disability

# %%
# download data
src_url   = 'https://data.london.gov.uk/download/2021-census-wards-qualifications-health-disability-and-care/a9f40c75-fbe5-4a52-acc5-d5a9ac496c4d/Disability.xlsx'
dest_path = os.path.join('data','ward_socioeconomic')

disability = pd.read_excel(
    cache_data(src_url, dest_path), 
    sheet_name='2021')
# Out:
# Found data/ward_socioeconomic/Disability.xlsx locally!

# %%
#check data cloumn names
disability.columns.to_list()
# Out:
# ['ward code',
#  'ward name',
#  'local authority code',
#  'local authority name',
#  'All Usual residents ',
#  'Disabled; activities limited a lot',
#  'Disabled; activities limited a little',
#  'Not disabled']

# %%
# Dropping the specified columns
disability = disability.drop(columns=['local authority code', 'local authority name'])
disability=disability.groupby('ward code').sum()
disability.head()
# Out:
#                          ward name  All Usual residents   \
# ward code
# E05009317            Bethnal Green                 21209
# E05009318  Blackwall & Cubitt Town                 21824
# E05009319                 Bow East                 19534
# E05009320                 Bow West                 13712
# E05009321            Bromley North                 11434
#
#            Disabled; activities limited a lot  \
# ward code
# E05009317                                1261
# E05009318                                 775
# E05009319                                1167
# E05009320                                 828
# E05009321                                 736
#
#            Disabled; activities limited a little  Not disabled
# ward code
# E05009317                                   1729         18219
# E05009318                                   1289         19760
# E05009319                                   1584         16783
# E05009320                                   1144         11740
# E05009321                                    911          9787

# %%
#add the proportion of disabled people
disability['disabled_pro'] = ((disability['Disabled; activities limited a lot']+disability['Disabled; activities limited a little'])/disability['All Usual residents ']).round(2)

# %%
disability.head()
# Out:
#                          ward name  All Usual residents   \
# ward code
# E05009317            Bethnal Green                 21209
# E05009318  Blackwall & Cubitt Town                 21824
# E05009319                 Bow East                 19534
# E05009320                 Bow West                 13712
# E05009321            Bromley North                 11434
#
#            Disabled; activities limited a lot  \
# ward code
# E05009317                                1261
# E05009318                                 775
# E05009319                                1167
# E05009320                                 828
# E05009321                                 736
#
#            Disabled; activities limited a little  Not disabled  disabled_pro
# ward code
# E05009317                                   1729         18219          0.14
# E05009318                                   1289         19760          0.09
# E05009319                                   1584         16783          0.14
# E05009320                                   1144         11740          0.14
# E05009321                                    911          9787          0.14

# %%
disability = disability.reset_index()

# %% [markdown]
# ## house_rent_price

# %%
# download data
src_url   = 'https://www.london.gov.uk/media/88817/download'
dest_path = os.path.join('data','ward_socioeconomic')

house_rent_price = pd.read_excel(
    cache_data(src_url, dest_path),header=[2])
# Out:
# Found data/ward_socioeconomic/download locally!

# %%
house_rent_price.head()
# Out:
#            Borough name          Ward name  One bedroom  Two bedrooms  \
# 0  Barking and Dagenham              Abbey   827.607183    919.563537
# 1  Barking and Dagenham             Alibon   745.092270    827.880300
# 2  Barking and Dagenham  Barking Riverside   981.192343   1090.213714
# 3  Barking and Dagenham               Beam   654.128228    726.809143
# 4  Barking and Dagenham          Becontree   721.867408    802.074898
#
#    Three bedrooms  Four bedrooms  Five bedrooms  Six bedrooms
# 0     1011.519890    1103.476244    1195.432598   1287.388951
# 1      910.668330     993.456360    1076.244390   1159.032420
# 2     1199.235085    1308.256457    1400.000000   1400.000000
# 3      799.490057     872.170971     944.851885   1017.532800
# 4      882.282388     962.489878    1042.697367   1122.904857

# %%
#check information of data
house_rent_price.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 680 entries, 0 to 679
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Borough name    680 non-null    object
#  1   Ward name       680 non-null    object
#  2   One bedroom     680 non-null    float64
#  3   Two bedrooms    680 non-null    float64
#  4   Three bedrooms  680 non-null    float64
#  5   Four bedrooms   680 non-null    float64
#  6   Five bedrooms   680 non-null    float64
#  7   Six bedrooms    680 non-null    float64
# dtypes: float64(6), object(2)
# memory usage: 42.6+ KB

# %%
house_rent_price.columns.to_list()
# Out:
# ['Borough name',
#  'Ward name',
#  'One bedroom',
#  'Two bedrooms',
#  'Three bedrooms',
#  'Four bedrooms',
#  'Five bedrooms',
#  'Six bedrooms']

# %%
# Dropping the specified columns
house_rent_price=house_rent_price.groupby('Ward name').sum()
house_rent_price.head()
# Out:
#                                Borough name  One bedroom  Two bedrooms  \
# Ward name
# Abbey            Barking and DagenhamMerton  1856.438836   2062.709818
# Abbey Road                      Westminster  1100.067184   1222.296871
# Abbey Wood                        Greenwich   823.022316    914.469240
# Abingdon             Kensington and Chelsea  1231.811425   1368.679361
# Addiscombe East                     Croydon   986.287446   1095.874941
#
#                  Three bedrooms  Four bedrooms  Five bedrooms  Six bedrooms
# Ward name
# Abbey               2268.980799    2475.251781    2595.432598   2687.388951
# Abbey Road          1344.526558    1400.000000    1400.000000   1400.000000
# Abbey Wood          1005.916164    1097.363088    1188.810012   1280.256936
# Abingdon            1400.000000    1400.000000    1400.000000   1400.000000
# Addiscombe East     1205.462435    1315.049929    1400.000000   1400.000000

# %%
#calculate mean ret price
house_rent_price['mean_rent_price'] = (house_rent_price.iloc[:, 1:].mean(axis=1)).round(2)
house_rent_price.head()
# Out:
#                                Borough name  One bedroom  Two bedrooms  \
# Ward name
# Abbey            Barking and DagenhamMerton  1856.438836   2062.709818
# Abbey Road                      Westminster  1100.067184   1222.296871
# Abbey Wood                        Greenwich   823.022316    914.469240
# Abingdon             Kensington and Chelsea  1231.811425   1368.679361
# Addiscombe East                     Croydon   986.287446   1095.874941
#
#                  Three bedrooms  Four bedrooms  Five bedrooms  Six bedrooms  \
# Ward name
# Abbey               2268.980799    2475.251781    2595.432598   2687.388951
# Abbey Road          1344.526558    1400.000000    1400.000000   1400.000000
# Abbey Wood          1005.916164    1097.363088    1188.810012   1280.256936
# Abingdon            1400.000000    1400.000000    1400.000000   1400.000000
# Addiscombe East     1205.462435    1315.049929    1400.000000   1400.000000
#
#                  mean_rent_price
# Ward name
# Abbey                    2324.37
# Abbey Road               1311.15
# Abbey Wood               1051.64
# Abingdon                 1366.75
# Addiscombe East          1233.78

# %%
house_rent_price['mean_rent_price'].isna()
# Out:
# Ward name
# Abbey                   False
# Abbey Road              False
# Abbey Wood              False
# Abingdon                False
# Addiscombe East         False
#                         ...
# Worcester Park North    False
# Worcester Park South    False
# Wormholt                False
# Yeading                 False
# Yiewsley                False
# Name: mean_rent_price, Length: 670, dtype: bool

# %%
house_rent_price = house_rent_price.reset_index()

# %%
#rename ward name to merge
house_rent_price.rename(columns={'Ward name': 'ward name'}, inplace=True)

# %% [markdown]
# ## crime_rate

# %%
src_url   = 'https://data.london.gov.uk/download/recorded_crime_summary/5daf1d8d-29b8-414f-bfe5-3f37566ef4c4/MPS%20Ward%20Level%20Crime%20%28most%20recent%2024%20months%29.csv'
dest_path = os.path.join('data','ward_socioeconomic')

crime = pd.read_csv(
    cache_data(src_url, dest_path))
# Out:
# Found data/ward_socioeconomic/MPS%20Ward%20Level%20Crime%20%28most%20recent%2024%20months%29.csv locally!

# %%
crime.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23438 entries, 0 to 23437
# Data columns (total 29 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   MajorText           23438 non-null  object
#  1   MinorText           23438 non-null  object
#  2   WardName            23438 non-null  object
#  3   WardCode            23438 non-null  object
#  4   LookUp_BoroughName  23438 non-null  object
#  5   202112              23438 non-null  int64
#  6   202201              23438 non-null  int64
#  7   202202              23438 non-null  int64
#  8   202203              23438 non-null  int64
#  9   202204              23438 non-null  int64
#  10  202205              23438 non-null  int64
#  11  202206              23438 non-null  int64
#  12  202207              23438 non-null  int64
#  13  202208              23438 non-null  int64
#  14  202209              23438 non-null  int64
#  15  202210              23438 non-null  int64
#  16  202211              23438 non-null  int64
#  17  202212              23438 non-null  int64
#  18  202301              23438 non-null  int64
#  19  202302              23438 non-null  int64
#  20  202303              23438 non-null  int64
#  21  202304              23438 non-null  int64
#  22  202305              23438 non-null  int64
#  23  202306              23438 non-null  int64
#  24  202307              23438 non-null  int64
#  25  202308              23438 non-null  int64
#  26  202309              23438 non-null  int64
#  27  202310              23438 non-null  int64
#  28  202311              23438 non-null  int64
# dtypes: int64(24), object(5)
# memory usage: 5.2+ MB

# %%
# Dropping the specified columns
crime = crime.drop(columns=['MajorText', 'MinorText', 'LookUp_BoroughName'])

# Grouping by 'WardName' and summing up the crime counts for each month
crime = crime.groupby('WardCode').sum()

crime.head()
# Out:
#                                                     WardName  202112  202201  \
# WardCode
# E05009317  Bethnal GreenBethnal GreenBethnal GreenBethnal...     181     202
# E05009318  Blackwall & Cubitt TownBlackwall & Cubitt Town...     138     129
# E05009319  Bow EastBow EastBow EastBow EastBow EastBow Ea...     148     170
# E05009320  Bow WestBow WestBow WestBow WestBow WestBow We...      87     115
# E05009321  Bromley NorthBromley NorthBromley NorthBromley...      91      82
#
#            202202  202203  202204  202205  202206  202207  202208  ...  \
# WardCode                                                           ...
# E05009317     195     192     204     244     188     194     176  ...
# E05009318     117     119     120     125     138     139     129  ...
# E05009319     148     169     195     207     163     177     166  ...
# E05009320     115     126     107     115      87     110     137  ...
# E05009321      71      81      92      96      76     105      99  ...
#
#            202302  202303  202304  202305  202306  202307  202308  202309  \
# WardCode
# E05009317     201     246     228     220     212     213     274     202
# E05009318     122     108     125     161     155     183     139     151
# E05009319     168     168     170     169     135     186     179     157
# E05009320     125     137     116     113     123     124     150     131
# E05009321      99      90      80     104      98     101     102     109
#
#            202310  202311
# WardCode
# E05009317     214     217
# E05009318     145     102
# E05009319     180     157
# E05009320     128     115
# E05009321     111     134
#
# [5 rows x 25 columns]

# %%
# Selecting the relevant columns for the year 2022
columns_2023 = crime[['202301','202302','202303','202304','202305',
                '202306','202307','202308','202309','202310']]
columns_2023
# Out:
#            202301  202302  202303  202304  202305  202306  202307  202308  \
# WardCode
# E05009317     223     201     246     228     220     212     213     274
# E05009318     131     122     108     125     161     155     183     139
# E05009319     160     168     168     170     169     135     186     179
# E05009320     130     125     137     116     113     123     124     150
# E05009321      99      99      90      80     104      98     101     102
# ...           ...     ...     ...     ...     ...     ...     ...     ...
# E05014115     134     122     150     136     163     127     150     137
# E05014116      55      53      63      53      58      58      61      50
# E05014117     164     139     141     155     155     222     141     181
# E05014118     347     372     339     379     392     429     420     402
# E05014119      58      53      79      82      77      78      61      81
#
#            202309  202310
# WardCode
# E05009317     202     214
# E05009318     151     145
# E05009319     157     180
# E05009320     131     128
# E05009321     109     111
# ...           ...     ...
# E05014115     126     126
# E05014116      73      52
# E05014117     196     215
# E05014118     349     357
# E05014119      80      71
#
# [679 rows x 10 columns]

# %%
# calculate avareage crime rate in every ward
crime['average_crime']= crime.iloc[:,1:].mean(axis=1).round(2)

# %%
crime = crime.reset_index()

# %%
crime.rename(columns={'WardCode': 'ward code'}, inplace=True)

# %%
crime.head()
# Out:
#    ward code                                           WardName  202112  \
# 0  E05009317  Bethnal GreenBethnal GreenBethnal GreenBethnal...     181
# 1  E05009318  Blackwall & Cubitt TownBlackwall & Cubitt Town...     138
# 2  E05009319  Bow EastBow EastBow EastBow EastBow EastBow Ea...     148
# 3  E05009320  Bow WestBow WestBow WestBow WestBow WestBow We...      87
# 4  E05009321  Bromley NorthBromley NorthBromley NorthBromley...      91
#
#    202201  202202  202203  202204  202205  202206  202207  ...  202303  \
# 0     202     195     192     204     244     188     194  ...     246
# 1     129     117     119     120     125     138     139  ...     108
# 2     170     148     169     195     207     163     177  ...     168
# 3     115     115     126     107     115      87     110  ...     137
# 4      82      71      81      92      96      76     105  ...      90
#
#    202304  202305  202306  202307  202308  202309  202310  202311  \
# 0     228     220     212     213     274     202     214     217
# 1     125     161     155     183     139     151     145     102
# 2     170     169     135     186     179     157     180     157
# 3     116     113     123     124     150     131     128     115
# 4      80     104      98     101     102     109     111     134
#
#    average_crime
# 0         209.46
# 1         134.58
# 2         164.42
# 3         119.96
# 4          95.54
#
# [5 rows x 27 columns]

# %% [markdown]
# ## age

# %%
src_url   = 'https://data.london.gov.uk/download/2021-census-wards-demography-and-migration/35b33393-f355-431b-9f87-ae55addaa636/Five%20year%20age%20bands.xlsx'
dest_path = os.path.join('data','ward_socioeconomic')

age = pd.read_excel(
    cache_data(src_url, dest_path), 
    sheet_name='2021')
# Out:
# Found data/ward_socioeconomic/Five%20year%20age%20bands.xlsx locally!

# %%
age.columns.to_list()
# Out:
# ['ward code',
#  'ward name',
#  'local authority code',
#  'local authority name',
#  'All usual residents',
#  'Aged 4 years and under',
#  'Aged 5 to 9 years',
#  'Aged 10 to 14 years',
#  'Aged 15 to 19 years',
#  'Aged 20 to 24 years',
#  'Aged 25 to 29 years',
#  'Aged 30 to 34 years',
#  'Aged 35 to 39 years',
#  'Aged 40 to 44 years',
#  'Aged 45 to 49 years',
#  'Aged 50 to 54 years',
#  'Aged 55 to 59 years',
#  'Aged 60 to 64 years',
#  'Aged 65 to 69 years',
#  'Aged 70 to 74 years',
#  'Aged 75 to 79 years',
#  'Aged 80 to 84 years',
#  'Aged 85 years and over']

# %%
# Dropping the specified columns
age = age.drop(columns=['local authority code', 'local authority name'])
age=age.groupby('ward code').sum()
age.head()
# Out:
#                          ward name  All usual residents  \
# ward code
# E05009317            Bethnal Green                21205
# E05009318  Blackwall & Cubitt Town                21816
# E05009319                 Bow East                19523
# E05009320                 Bow West                13733
# E05009321            Bromley North                11431
#
#            Aged 4 years and under  Aged 5 to 9 years  Aged 10 to 14 years  \
# ward code
# E05009317                    1303               1343                 1218
# E05009318                    1212               1007                  919
# E05009319                    1128                967                  952
# E05009320                     860                695                  704
# E05009321                     814                774                  687
#
#            Aged 15 to 19 years  Aged 20 to 24 years  Aged 25 to 29 years  \
# ward code
# E05009317                 1949                 2192                 2647
# E05009318                  919                 2653                 3997
# E05009319                  898                 1495                 3028
# E05009320                  662                 1228                 1778
# E05009321                  654                  979                 1410
#
#            Aged 30 to 34 years  Aged 35 to 39 years  Aged 40 to 44 years  \
# ward code
# E05009317                 2428                 1807                 1522
# E05009318                 3519                 2363                 1582
# E05009319                 3122                 2178                 1430
# E05009320                 1760                 1310                  918
# E05009321                 1441                 1140                  858
#
#            Aged 45 to 49 years  Aged 50 to 54 years  Aged 55 to 59 years  \
# ward code
# E05009317                 1131                  973                  796
# E05009318                 1132                  761                  594
# E05009319                  960                  849                  787
# E05009320                  775                  750                  624
# E05009321                  677                  539                  468
#
#            Aged 60 to 64 years  Aged 65 to 69 years  Aged 70 to 74 years  \
# ward code
# E05009317                  654                  469                  302
# E05009318                  388                  250                  205
# E05009319                  568                  379                  283
# E05009320                  514                  410                  305
# E05009321                  340                  256                  139
#
#            Aged 75 to 79 years  Aged 80 to 84 years  Aged 85 years and over
# ward code
# E05009317                  190                  139                     142
# E05009318                  140                   99                      76
# E05009319                  191                  143                     165
# E05009320                  184                  125                     131
# E05009321                  104                   88                      63

# %%
#according to the census, young people age include 15-24
age['young_people']=((age['Aged 15 to 19 years']+age['Aged 20 to 24 years'])/age['All usual residents']).round(2)
#according to the census, children and teenager age include 0-14
age['children_teenager']=((age['Aged 4 years and under']+age['Aged 5 to 9 years']+age['Aged 10 to 14 years'])/age['All usual residents']).round(2)
#according to the census, old people age include 65+
age['old_people']=((age['Aged 65 to 69 years']+age['Aged 70 to 74 years']+age['Aged 75 to 79 years']+age['Aged 80 to 84 years']+age['Aged 85 years and over'])/age['All usual residents']).round(2)

# %%
age['middle_aged']=(1-(age['young_people']+age['children_teenager']+age['old_people'])).round(2)

# %%
age.head()
# Out:
#                          ward name  All usual residents  \
# ward code
# E05009317            Bethnal Green                21205
# E05009318  Blackwall & Cubitt Town                21816
# E05009319                 Bow East                19523
# E05009320                 Bow West                13733
# E05009321            Bromley North                11431
#
#            Aged 4 years and under  Aged 5 to 9 years  Aged 10 to 14 years  \
# ward code
# E05009317                    1303               1343                 1218
# E05009318                    1212               1007                  919
# E05009319                    1128                967                  952
# E05009320                     860                695                  704
# E05009321                     814                774                  687
#
#            Aged 15 to 19 years  Aged 20 to 24 years  Aged 25 to 29 years  \
# ward code
# E05009317                 1949                 2192                 2647
# E05009318                  919                 2653                 3997
# E05009319                  898                 1495                 3028
# E05009320                  662                 1228                 1778
# E05009321                  654                  979                 1410
#
#            Aged 30 to 34 years  Aged 35 to 39 years  ...  Aged 60 to 64 years  \
# ward code                                            ...
# E05009317                 2428                 1807  ...                  654
# E05009318                 3519                 2363  ...                  388
# E05009319                 3122                 2178  ...                  568
# E05009320                 1760                 1310  ...                  514
# E05009321                 1441                 1140  ...                  340
#
#            Aged 65 to 69 years  Aged 70 to 74 years  Aged 75 to 79 years  \
# ward code
# E05009317                  469                  302                  190
# E05009318                  250                  205                  140
# E05009319                  379                  283                  191
# E05009320                  410                  305                  184
# E05009321                  256                  139                  104
#
#            Aged 80 to 84 years  Aged 85 years and over  young_people  \
# ward code
# E05009317                  139                     142          0.20
# E05009318                   99                      76          0.16
# E05009319                  143                     165          0.12
# E05009320                  125                     131          0.14
# E05009321                   88                      63          0.14
#
#            children_teenager  old_people  middle_aged
# ward code
# E05009317               0.18        0.06         0.56
# E05009318               0.14        0.04         0.66
# E05009319               0.16        0.06         0.66
# E05009320               0.16        0.08         0.62
# E05009321               0.20        0.06         0.60
#
# [5 rows x 24 columns]

# %%
age = age.reset_index()

# %%
age
# Out:
#      ward code                ward name  All usual residents  \
# 0    E05009317            Bethnal Green                21205
# 1    E05009318  Blackwall & Cubitt Town                21816
# 2    E05009319                 Bow East                19523
# 3    E05009320                 Bow West                13733
# 4    E05009321            Bromley North                11431
# ..         ...                      ...                  ...
# 675  E05014116          Streatham Wells                 9879
# 676  E05014117                 Vauxhall                 9633
# 677  E05014118    Waterloo & South Bank                 8872
# 678  E05014119             West Dulwich                11505
# 679  E09000001           City of London                 8586
#
#      Aged 4 years and under  Aged 5 to 9 years  Aged 10 to 14 years  \
# 0                      1303               1343                 1218
# 1                      1212               1007                  919
# 2                      1128                967                  952
# 3                       860                695                  704
# 4                       814                774                  687
# ..                      ...                ...                  ...
# 675                     543                540                  475
# 676                     350                296                  310
# 677                     254                263                  290
# 678                     681                701                  720
# 679                     216                161                  173
#
#      Aged 15 to 19 years  Aged 20 to 24 years  Aged 25 to 29 years  \
# 0                   1949                 2192                 2647
# 1                    919                 2653                 3997
# 2                    898                 1495                 3028
# 3                    662                 1228                 1778
# 4                    654                  979                 1410
# ..                   ...                  ...                  ...
# 675                  386                  520                 1150
# 676                  493                 1356                 1683
# 677                  770                 1464                 1222
# 678                  565                  523                  968
# 679                  215                  962                 1213
#
#      Aged 30 to 34 years  ...  Aged 60 to 64 years  Aged 65 to 69 years  \
# 0                   2428  ...                  654                  469
# 1                   3519  ...                  388                  250
# 2                   3122  ...                  568                  379
# 3                   1760  ...                  514                  410
# 4                   1441  ...                  340                  256
# ..                   ...  ...                  ...                  ...
# 675                 1210  ...                  380                  303
# 676                 1138  ...                  317                  214
# 677                  846  ...                  363                  280
# 678                 1117  ...                  529                  417
# 679                 1003  ...                  460                  390
#
#      Aged 70 to 74 years  Aged 75 to 79 years  Aged 80 to 84 years  \
# 0                    302                  190                  139
# 1                    205                  140                   99
# 2                    283                  191                  143
# 3                    305                  184                  125
# 4                    139                  104                   88
# ..                   ...                  ...                  ...
# 675                  238                  159                  140
# 676                  139                  102                   78
# 677                  226                  150                  112
# 678                  412                  255                  143
# 679                  322                  209                  162
#
#      Aged 85 years and over  young_people  children_teenager  old_people  \
# 0                       142          0.20               0.18        0.06
# 1                        76          0.16               0.14        0.04
# 2                       165          0.12               0.16        0.06
# 3                       131          0.14               0.16        0.08
# 4                        63          0.14               0.20        0.06
# ..                      ...           ...                ...         ...
# 675                     138          0.09               0.16        0.10
# 676                      75          0.19               0.10        0.06
# 677                      98          0.25               0.09        0.10
# 678                     148          0.09               0.18        0.12
# 679                     127          0.14               0.06        0.14
#
#      middle_aged
# 0           0.56
# 1           0.66
# 2           0.66
# 3           0.62
# 4           0.60
# ..           ...
# 675         0.65
# 676         0.65
# 677         0.56
# 678         0.61
# 679         0.66
#
# [680 rows x 25 columns]

# %% [markdown]
# ## deprivation:poverty

# %%
src_url   = 'https://data.london.gov.uk/download/2021-census-wards-demography-and-migration/05b99a3e-7e9a-467d-8d73-8417ee42bc9f/Household%20deprivation.xlsx'
dest_path = os.path.join('data','ward_socioeconomic')

household_deprivation = pd.read_excel(
    cache_data(src_url, dest_path), 
    sheet_name='2021')
# Out:
# Found data/ward_socioeconomic/Household%20deprivation.xlsx locally!

# %%
# Dropping the specified columns
household_deprivation = household_deprivation.drop(columns=['local authority code', 'local authority name'])
household_deprivation=household_deprivation.groupby('ward code').sum()
household_deprivation.head()
# Out:
#                          ward name  All Households  \
# ward code
# E05009317            Bethnal Green            7370
# E05009318  Blackwall & Cubitt Town            9694
# E05009319                 Bow East            8429
# E05009320                 Bow West            5280
# E05009321            Bromley North            4421
#
#            deprived in: no dimensions  1 dimension  2 dimensions  \
# ward code
# E05009317                        2898         2519          1379
# E05009318                        5391         2974           929
# E05009319                        4234         2426          1280
# E05009320                        2387         1707           876
# E05009321                        1784         1458           813
#
#            3 dimensions  4 dimensions
# ward code
# E05009317           531            43
# E05009318           366            34
# E05009319           450            39
# E05009320           284            26
# E05009321           332            34

# %%
#add household_deprivation_rate
household_deprivation['household_deprivation_rate']=((household_deprivation['All Households']-household_deprivation['deprived in: no dimensions'])/household_deprivation['All Households']).round(2)

# %%
household_deprivation.sample(5)
# Out:
#                         ward name  All Households  deprived in: no dimensions  \
# ward code
# E05013557            Rayners Lane            3060                        1604
# E05013736  College Park & Old Oak            3885                        1483
# E05011475    Park Hill & Whitgift            2392                        1337
# E05013582                Wood End            6186                        2157
# E05013934   Green Lane & St James            2372                        1179
#
#            1 dimension  2 dimensions  3 dimensions  4 dimensions  \
# ward code
# E05013557         1055           353            47             1
# E05013736         1408           720           253            21
# E05011475          733           264            51             7
# E05013582         2299          1319           367            44
# E05013934          752           337           100             4
#
#            household_deprivation_rate
# ward code
# E05013557                        0.48
# E05013736                        0.62
# E05011475                        0.44
# E05013582                        0.65
# E05013934                        0.50

# %%
household_deprivation = household_deprivation.reset_index()

# %% [markdown]
# ## creat whole socioeconomics dataset

# %%
# build up initial datafrmae
neighbor_socioeconomic=status[['ward code','ward name','nonwork_rate','middle_high_class_pro','advanced_education_rate']]

# %%
neighbor_socioeconomic.head()
# Out:
#    ward code                ward name  nonwork_rate  middle_high_class_pro  \
# 0  E05009317            Bethnal Green          0.14                   0.41
# 1  E05009318  Blackwall & Cubitt Town          0.09                   0.58
# 2  E05009319                 Bow East          0.11                   0.54
# 3  E05009320                 Bow West          0.11                   0.50
# 4  E05009321            Bromley North          0.17                   0.41
#
#    advanced_education_rate
# 0                     0.19
# 1                     0.13
# 2                     0.09
# 3                     0.10
# 4                     0.11

# %%
common_key='ward code'

# add every column into the first dataset
neighbor_socioeconomic = neighbor_socioeconomic.merge(method_of_work[[common_key, 'public_transport_station_coverage']], on=common_key, how='left')
neighbor_socioeconomic = neighbor_socioeconomic.merge(commute_distance[[common_key, 'average_commute_distance']], on=common_key, how='left')
neighbor_socioeconomic = neighbor_socioeconomic.merge(health[[common_key, 'All Usual residents','unhealthy_rate']], on=common_key, how='left')
neighbor_socioeconomic = neighbor_socioeconomic.merge(disability[[common_key, 'disabled_pro']], on=common_key, how='left')
neighbor_socioeconomic = neighbor_socioeconomic.merge(crime[[common_key, 'average_crime']], on=common_key, how='left')
neighbor_socioeconomic = neighbor_socioeconomic.merge(age[[common_key, 'young_people','children_teenager','old_people','middle_aged']], on=common_key, how='left')
neighbor_socioeconomic = neighbor_socioeconomic.merge(household_deprivation[[common_key, 'household_deprivation_rate']], on=common_key, how='left')
neighbor_socioeconomic = neighbor_socioeconomic.merge(house_rent_price[['ward name', 'mean_rent_price']], on='ward name', how='left')

# %%
neighbor_socioeconomic.head()
# Out:
#    ward code                ward name  nonwork_rate  middle_high_class_pro  \
# 0  E05009317            Bethnal Green          0.14                   0.41
# 1  E05009318  Blackwall & Cubitt Town          0.09                   0.58
# 2  E05009319                 Bow East          0.11                   0.54
# 3  E05009320                 Bow West          0.11                   0.50
# 4  E05009321            Bromley North          0.17                   0.41
#
#    advanced_education_rate  public_transport_station_coverage  \
# 0                     0.19                               0.45
# 1                     0.13                               0.56
# 2                     0.09                               0.47
# 3                     0.10                               0.45
# 4                     0.11                               0.56
#
#    average_commute_distance  All Usual residents  unhealthy_rate  disabled_pro
# 0                      3.24                21219            0.05          0.14
# 1                      2.74                21823            0.03          0.09
# 2                      2.72                19535            0.05          0.14
# 3                      2.96                13713            0.05          0.14
# 4                      3.83                11436            0.06          0.14

# %%
#Save to csv
neighbor_socioeconomic.to_csv('Neighbourdata_Cleaned.csv')

# %%
#check info
eighbor_socioeconomic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 680 entries, 0 to 679
# Data columns (total 17 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   ward code                          680 non-null    object
#  1   ward name                          680 non-null    object
#  2   nonwork_rate                       680 non-null    float64
#  3   middle_high_class_pro              680 non-null    float64
#  4   advanced_education_rate            680 non-null    float64
#  5   public_transport_station_coverage  680 non-null    float64
#  6   average_commute_distance           680 non-null    float64
#  7   All Usual residents                680 non-null    int64
#  8   unhealthy_rate                     680 non-null    float64
#  9   disabled_pro                       680 non-null    float64
#  10  average_crime                      679 non-null    float64
#  11  young_people                       680 non-null    float64
#  12  children_teenager                  680 non-null    float64
#  13  old_people                         680 non-null    float64
#  14  middle_aged                        680 non-null    float64
#  15  household_deprivation_rate         680 non-null    float64
#  16  mean_rent_price                    672 non-null    float64
# dtypes: float64(14), int64(1), object(2)
# memory usage: 90.4+ KB

# %% [markdown]
# # zhi biao
# commute_distance["average_commute_distance"] 2
#
# health['unhealthy_rate']3 4
#
# disability['disabled_pro']5
#
# houseprice_2022['median_houseprice_2022']6
#
# house_rent_price['mean_rent_price'] 7
#
# crime_sum_ward = crime_sum_2023.groupby('WardName')['avarge_crime'] 8
#
# young_people	children_teenager	old_people	middle_aged 12
#
# household_deprivation['household_deprivation_rate'] 13

# %%
#read airbnb data
airbnb_file = 'data/airbnb_wardnumber_clean.csv'
airbnb_data = pd.read_csv(airbnb_file)

# %%
airbnb_data.head()
# Out:
#    Unnamed: 0     WD22CD  total_room  Entire home/apt  Hotel room  \
# 0           0  E05009294          27             27.0         0.0
# 1           1  E05009317         388            180.0         0.0
# 2           2  E05009318         374            227.0         0.0
# 3           3  E05009319         432            256.0         0.0
# 4           4  E05009320         282            156.0         1.0
#
#    Private room  Shared room   avg_price  avg_minimum_nights  \
# 0           0.0          0.0  158.370370            6.555556
# 1         206.0          2.0  109.103093            4.979381
# 2         143.0          4.0  141.473262            5.409091
# 3         175.0          1.0  112.254630            3.942130
# 4         118.0          7.0  105.971631            3.868794
#
#    avg_reviews_per_month  avg_availability_365  avg_star_rate
# 0               1.952917             36.962963       4.660667
# 1               0.872397             91.185567       4.675286
# 2               1.295324            124.737968       4.666619
# 3               0.853971             74.125000       4.780307
# 4               0.874266             84.152482       4.717365

# %%
# Rename the column in Airbnb data to match the Neighbourhood data
airbnb_data = airbnb_data.rename(columns={"WD22CD": "ward code"})

# %%
# Merge the two datasets on 'ward name'
merged_data = pd.merge(airbnb_data, neighbor_socioeconomic, on="ward code", how="left")

# Display the first few rows of the merged dataframe
merged_data.head()
# Out:
#    Unnamed: 0  ward code  total_room  Entire home/apt  Hotel room  \
# 0           0  E05009294          27             27.0         0.0
# 1           1  E05009317         388            180.0         0.0
# 2           2  E05009318         374            227.0         0.0
# 3           3  E05009319         432            256.0         0.0
# 4           4  E05009320         282            156.0         1.0
#
#    Private room  Shared room   avg_price  avg_minimum_nights  \
# 0           0.0          0.0  158.370370            6.555556
# 1         206.0          2.0  109.103093            4.979381
# 2         143.0          4.0  141.473262            5.409091
# 3         175.0          1.0  112.254630            3.942130
# 4         118.0          7.0  105.971631            3.868794
#
#    avg_reviews_per_month  ...  All Usual residents  unhealthy_rate  \
# 0               1.952917  ...                  NaN             NaN
# 1               0.872397  ...              21219.0            0.05
# 2               1.295324  ...              21823.0            0.03
# 3               0.853971  ...              19535.0            0.05
# 4               0.874266  ...              13713.0            0.05
#
#   disabled_pro  average_crime  young_people  children_teenager  old_people  \
# 0          NaN            NaN           NaN                NaN         NaN
# 1         0.14         209.46          0.20               0.18        0.06
# 2         0.09         134.58          0.16               0.14        0.04
# 3         0.14         164.42          0.12               0.16        0.06
# 4         0.14         119.96          0.14               0.16        0.08
#
#    middle_aged  household_deprivation_rate  mean_rent_price
# 0          NaN                         NaN              NaN
# 1         0.56                        0.61          1328.37
# 2         0.66                        0.44          1348.40
# 3         0.66                        0.50          1315.48
# 4         0.62                        0.55          1302.59
#
# [5 rows x 28 columns]

# %%
#Save to csv
merged_data.to_csv('Airbnb_Merged.csv')
